# %%
import matplotlib.pyplot as plt
from glue_sessions import *
from psychometric_curves import *
from my_fun.my_fun import fig_size, save_notebook_files

# %%
# Magics
# %load_ext autoreload
# %autoreload 2

# %%
# Plotting style
style_path = os.path.expanduser('~/PycharmProjects/alexis_style.mplstyle')
plt.style.use(style_path)
# %config InlineBackend.figure_format = 'svg'
# %config InlineBackend.figure_format = 'retina'

# %%
figsize = fig_size(n_cols=2)
figsize = (figsize[0], figsize[0])

# %% [markdown]
# # Example mouse

# %%
plot_pc(experiment='2AFC_2', animal='333', kind='prob_right', figsize=figsize)
plt.ylabel('$p$(right)')
plt.title('Best mouse\n'
          '(#333, $N$=25k trials)')
# Out:
# Removed 2780 trials from session start (AW and Warm Up trials)
# Total:12k trials
# Text(0.5, 1.0, 'Best mouse\n(#333, $N$=25k trials)')

# %%
plot_pc(experiment='2AFC_2', animal='333', kind='prob_rep', figsize=figsize)
plt.ylabel('$p$(repeat)')
plt.title('Best mouse\n'
          '(#333, $N$=25k trials)')
# Out:
# Removed 2780 trials from session start (AW and Warm Up trials)
# Total:12k trials
# Text(0.5, 1.0, 'Best mouse\n(#333, $N$=25k trials)')

# %% [markdown]
# # Group 2

# %% [markdown]
# ## Single subjects

# %%
# experiment = '2AFC_2'
# animal = main(experiment)[experiment]
# plot_pc(experiment=experiment, animal=animal, kind=kind, figsize=figsize)

# %% [markdown]
# ## Mean

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_2', animals=None, kind='prob_right', figsize=figsize)
plt.title('Group 2')
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_2', animals=None, kind='prob_rep', figsize=figsize)
plt.title('Group 2')
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %% [markdown]
# # Group 3

# %% [markdown]
# ## Single subjects

# %%
# experiment = '2AFC_3'
# animal = main(experiment)[experiment]
# plot_pc(experiment=experiment, animal=animal, kind=kind, figsize=figsize)

# %% [markdown]
# ## Mean

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_3', animals=None, kind='prob_right', figsize=figsize)
plt.title('Group 3')
# Out:
# Cherry picking for experiment: 2AFC_3
# Number of responded trials in data collection (with evidences):
# 387: 0 trials
# 395: 0 trials
# 398: 0 trials
# 419: 10403 trials
# 420: 20117 trials
# 422: 21061 trials
# 501: 0 trials
# 614: 0 trials
# 615: 0 trials
# 616: 14090 trials
# 617: 1728 trials
# 618: 0 trials
# 619: 7257 trials
# 620: 949 trials
# 623: 13642 trials
# 625: 0 trials
# 627: 0 trials
#
#
# Subjects left behind (never learnt):
# 387: 0 trials
# 395: 0 trials
# 398: 0 trials
# 501: 0 trials
# 614: 0 trials
# 615: 0 trials
# 618: 0 trials
# 620: 949 trials
# 625: 0 trials
# 627: 0 trials
#
#
# Removed 3120 trials from session start (AW and Warm Up trials)
# Total:21k trials
# Removed 3800 trials from session start (AW and Warm Up trials)
# Total:12k trials
# Removed 3560 trials from session start (AW and Warm Up trials)
# Total:16k trials
# Removed 3960 trials from session start (AW and Warm Up trials)
# Total:26k trials
# ...

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_3', animals=None, kind='prob_rep', figsize=figsize)
plt.title('Group 3')
# Out:
# Cherry picking for experiment: 2AFC_3
# Number of responded trials in data collection (with evidences):
# 387: 0 trials
# 395: 0 trials
# 398: 0 trials
# 419: 10403 trials
# 420: 20117 trials
# 422: 21061 trials
# 501: 0 trials
# 614: 0 trials
# 615: 0 trials
# 616: 14090 trials
# 617: 1728 trials
# 618: 0 trials
# 619: 7257 trials
# 620: 949 trials
# 623: 13642 trials
# 625: 0 trials
# 627: 0 trials
#
#
# Subjects left behind (never learnt):
# 387: 0 trials
# 395: 0 trials
# 398: 0 trials
# 501: 0 trials
# 614: 0 trials
# 615: 0 trials
# 618: 0 trials
# 620: 949 trials
# 625: 0 trials
# 627: 0 trials
#
#
# Removed 3120 trials from session start (AW and Warm Up trials)
# Total:21k trials
# Removed 3800 trials from session start (AW and Warm Up trials)
# Total:12k trials
# Removed 3560 trials from session start (AW and Warm Up trials)
# Total:16k trials
# Removed 3960 trials from session start (AW and Warm Up trials)
# Total:26k trials
# ...

# %% [markdown]
# # Group 4

# %% [markdown]
# ## Single subjects

# %%
# experiment = '2AFC_4'
# animal = main(experiment)[experiment]
# plot_pc(experiment=experiment, animal=animal, kind=kind, figsize=figsize)

# %% [markdown]
# ## Mean

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_4', animals=None, kind='prob_right', figsize=figsize)
plt.title('Group 4')
# Out:
# Cherry picking for experiment: 2AFC_4
# Number of responded trials in data collection (with evidences):
# 561: 8079 trials
# 562: 0 trials
# 791: 0 trials
# 801: 0 trials
# 802: 0 trials
# 804: 0 trials
# 807: 4259 trials
# 808: 0 trials
# 820: 31998 trials
# 821: 37049 trials
# 873: 25979 trials
# 875: 16135 trials
# 876: 2504 trials
# 907: 36258 trials
# 909: 13755 trials
# 911: 35334 trials
#
#
# Subjects left behind (never learnt):
# 562: 0 trials
# 791: 0 trials
# 801: 0 trials
# 802: 0 trials
# 804: 0 trials
# 808: 0 trials
#
#
# Removed 2297 trials from session start (AW and Warm Up trials)
# Total:30k trials
# Removed 2224 trials from session start (AW and Warm Up trials)
# Total:24k trials
# Removed 6360 trials from session start (AW and Warm Up trials)
# Total:64k trials
# Removed 6090 trials from session start (AW and Warm Up trials)
# Total:36k trials
# Removed 4205 trials from session start (AW and Warm Up trials)
# Total:30k trials
# ...

# %%
figsize = fig_size(n_cols=3)
figsize = figsize[0], figsize[0]
plot_mean_pc(experiment='2AFC_4', animals=None, kind='prob_rep', figsize=figsize)
plt.title('Group 4')
# Out:
# Cherry picking for experiment: 2AFC_4
# Number of responded trials in data collection (with evidences):
# 561: 8079 trials
# 562: 0 trials
# 791: 0 trials
# 801: 0 trials
# 802: 0 trials
# 804: 0 trials
# 807: 4259 trials
# 808: 0 trials
# 820: 31998 trials
# 821: 37049 trials
# 873: 25979 trials
# 875: 16135 trials
# 876: 2504 trials
# 907: 36258 trials
# 909: 13755 trials
# 911: 35334 trials
#
#
# Subjects left behind (never learnt):
# 562: 0 trials
# 791: 0 trials
# 801: 0 trials
# 802: 0 trials
# 804: 0 trials
# 808: 0 trials
#
#
# Removed 2297 trials from session start (AW and Warm Up trials)
# Total:30k trials
# Removed 2224 trials from session start (AW and Warm Up trials)
# Total:24k trials
# Removed 6360 trials from session start (AW and Warm Up trials)
# Total:64k trials
# Removed 6090 trials from session start (AW and Warm Up trials)
# Total:36k trials
# Removed 4205 trials from session start (AW and Warm Up trials)
# Total:30k trials
# ...

# %% [markdown]
# # Groups 2-4

# %% [markdown]
# ## Single subjects

# %%
plot_all_pcs(experiment=None, animals=None, kind='prob_right', ncols=5)
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %%
plot_all_pcs(experiment=None, animals=None, kind='prob_rep', ncols=5)
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %% [markdown]
# # Mean

# %%
figsize = fig_size(n_cols=2)
figsize = (figsize[0], figsize[0])

# %%
plot_pc_across_batches(experiments=None, kind='prob_right', save=False, figsize=figsize)
plt.ylabel('$p$(right)')
plt.title('All mice\n'
          '$N$=25 mice, 431k trials)')
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %%
plot_pc_across_batches(experiments=None, kind='prob_rep', save=False, figsize=figsize)
plt.ylabel('$p$(repeat)')
plt.title('All mice\n'
          '$N$=25 mice, 431k trials)')
# Out:
# Cherry picking for experiment: 2AFC_2
# Number of responded trials in data collection (with evidences):
# 325: 7279 trials
# 326: 2211 trials
# 327: 9386 trials
# 328: 0 trials
# 329: 11541 trials
# 330: 4658 trials
# 331: 0 trials
# 332: 27879 trials
# 333: 25533 trials
# 334: 102 trials
# 335: 12712 trials
# 337: 20602 trials
#
#
# Subjects left behind (never learnt):
# 328: 0 trials
# 331: 0 trials
# 334: 102 trials
#
#
# Removed 1499 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 1380 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 926 trials from session start (AW and Warm Up trials)
# Total:11k trials
# Removed 1628 trials from session start (AW and Warm Up trials)
# Total:18k trials
# Removed 1720 trials from session start (AW and Warm Up trials)
# Total:20k trials
# Removed 3084 trials from session start (AW and Warm Up trials)
# Total:17k trials
# Removed 2780 trials from session start (AW and Warm Up trials)
# ...

# %% [markdown]
# # Group 5
# Ephys group, no evidences, no PCs

# %% [markdown]
# # Group 6
# Pharma group (MK-801)

# %%
# # Set parameters
# experiment = '2AFC_6'  # Set the experiment (batch)
# animals = ['014', '016', '017', '020', '021', '022', '023', '024', '025']

# %%
# Glue the last sessions
# update_glued_sessions(experiment='2AFC_6')

# %% [markdown]
# ## Prob. right

# %%
# kind = 'prob_right'

# %% [markdown]
# ### Single animals

# %%
# psych_curves_rest = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=None, save=False, format='png', transparent=False)
# psych_curves_saline = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=0, save=False, format='png', transparent=False)
# psych_curves_drug = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=1, save=False, format='png', transparent=False)

# %% [markdown]
# ### Grouped animals

# %% [markdown]
# #### Rest

# %%
# psych_curve_rest = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=None, format='png', transparent=False)  # Rest

# %% [markdown]
# #### Saline

# %%
# psych_curve_saline = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=0, format='png', transparent=False)  # Saline

# %% [markdown]
# #### Drug

# %%
# psych_curve_drug = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=1, format='png', transparent=False)  # Drug (MK-801)

# %% [markdown]
# ## Prob. repeat

# %%
# kind = 'prob_rep'

# %% [markdown]
# ### Single animals

# %%
# psych_curves_rest = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=None, save=False, format='png', transparent=False)
# psych_curves_saline = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=0, save=False, format='png', transparent=False)
# psych_curves_drug = plot_pcs(experiment=experiment, animals=animals, kind=kind, drug=1, save=False, format='png', transparent=False)

# %% [markdown]
# ### Grouped animals

# %% [markdown]
# #### Rest

# %%
# psych_curve_drug = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=None, format='png', transparent=False)  # Drug (MK-801)

# %% [markdown]
# #### Saline

# %%
# psych_curve_saline = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=0, format='png', transparent=False)  # Saline

# %% [markdown]
# #### Drug

# %%
# psych_curve_drug = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=1, format='png', transparent=False)  # Drug (MK-801)

# %% [markdown]
# # Save all notebook's figures

# %%
# # Whole notebook outputs (no input or prompt, only Markdown and figures)
# # As HTML
# !jupyter nbconvert notebook.ipynb --to html --no-input --no-prompt
# # As PDF
# !jupyter nbconvert notebook.ipynb --to pdf --no-input --no-prompt
#
# Export all figures
save_notebook_files(notebook_path='notebook.ipynb')
# Out:
# Saved 12 images to notebook_files/
