# %%
from glue_sessions import *
from psychometric_curves import *

# %%
# Glue the last sessions
update_glued_sessions(protocol='stage_training_v6', experiment='2AFC_6')

# %%
# Set the experiment (batch)
experiment = '2AFC_6'

# %% [markdown]
# # Probability choose RIGHT

# %%
kind = 'prob_right'

# %% [markdown]
# ## Single animals

# %%
psych_curves = plot_pcs(experiment=experiment, animals=['014', '015', '016', '017'], kind=kind, save=False, format='png', transparent=False)
# Out:
# plot_pc took 0.12 seconds to run
# 015 does not have enough trials
# plot_pc took 0.11 seconds to run
# plot_pc took 0.09 seconds to run
# plot_pcs took 0.43 seconds to run

# %% [markdown]
# # Grouped animals

# %%
psych_curve = plot_pc_across_animals(experiment='2AFC_6', animals=['014', '015', '016', '017'], save=False, kind=kind, format='png', transparent=False)
# Out:
# Animal 015 has 7 ILDs, not 9. Need more trials. Skipping...
# plot_pc_across_animals took 0.33 seconds to run

# %% [markdown]
# # Probability choose REPEAT

# %%
kind = 'prob_rep'

# %% [markdown]
# ## Single animals

# %%
psych_curves = plot_pcs(experiment=experiment, animals=['014', '015', '016', '017'], kind=kind, save=False, format='png', transparent=False)
# Out:
# plot_pc took 0.10 seconds to run
# 015 does not have enough trials
# plot_pc took 0.10 seconds to run
# plot_pc took 0.15 seconds to run
# plot_pcs took 0.49 seconds to run
# C:\Users\Usuario\PycharmProjects\my_fun\my_fun.py:740: RuntimeWarning: overflow encountered in exp
#   y_pred = b + (1 - b - p) / (1 + np.exp(-k * (xdata - x0)))
# C:\Users\Usuario\PycharmProjects\my_fun\my_fun.py:740: RuntimeWarning: overflow encountered in exp
#   y_pred = b + (1 - b - p) / (1 + np.exp(-k * (xdata - x0)))
# C:\Users\Usuario\PycharmProjects\my_fun\my_fun.py:763: RuntimeWarning: overflow encountered in exp
#   fit = b + (1 - b - p) / (1 + np.exp(-k * (np.linspace(np.min(x), np.max(x), n_points) - x0)))

# %% [markdown]
# ## Grouped animals

# %%
psych_curve = plot_pc_across_animals(experiment='2AFC_6', animals=['014', '015', '016', '017'], save=False, kind=kind, format='png', transparent=False)
# Out:
# Animal 015 has 7 ILDs, not 9. Need more trials. Skipping...
# plot_pc_across_animals took 0.34 seconds to run
