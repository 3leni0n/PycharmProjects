# %%
from glue_sessions import *
from psychometric_curves import *

# %%
# Glue the last sessions
# update_glued_sessions(protocol='stage_training_v6', experiment='2AFC_6')

# %%
# Set the experiment (batch)
experiment = '2AFC_6'

# %%
# Choose drug condition
drug = 1  # np.nan = rest, 0 = saline, 1 = drug (MK-801)

# %% [markdown]
# # Probability choose RIGHT

# %%
kind = 'prob_right'

# %% [markdown]
# ## Single animals

# %%
# psych_curves = plot_pcs(experiment=experiment, animals=['014', '016', '017', '020', '021', '022', '023', '024', '025'], kind=kind, save=False, format='png', transparent=False)

# %% [markdown]
# # Grouped animals

# %%
psych_curve = plot_pc_across_animals(experiment='2AFC_6', animals=['014', '016', '017', '020', '021', '022', '023', '024', '025'], save=False, kind=kind, drug=drug, format='png', transparent=False)
# Out:
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_pc_across_animals took 0.97 seconds to run

# %% [markdown]
# # Probability choose REPEAT

# %%
kind = 'prob_rep'

# %% [markdown]
# ## Single animals

# %%
# psych_curves = plot_pcs(experiment=experiment, animals=['014', '016', '017', '020', '021', '022', '023', '024', '025'], kind=kind, save=False, format='png', transparent=False)

# %% [markdown]
# ## Grouped animals

# %%
psych_curve = plot_pc_across_animals(experiment='2AFC_6', animals=['014', '016', '017', '020', '021', '022', '023', '024', '025'], save=False, kind=kind, drug=drug, format='png', transparent=False)
# Out:
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_pc_across_animals took 0.99 seconds to run
