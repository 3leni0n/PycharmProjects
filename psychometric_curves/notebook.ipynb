# %%
import matplotlib.pyplot as plt

from glue_sessions import *
from psychometric_curves import *

# %%
# Glue the last sessions
# update_glued_sessions(protocol='stage_training_v6', experiment='2AFC_6')

# %%
# Set parameters
experiment = '2AFC_6'  # Set the experiment (batch)
animals = ['014', '016', '017', '020', '021', '022', '023', '024', '025']

# %% [markdown]
# # Probability choose RIGHT

# %% [markdown]
# ## Single animals

# %%
# psych_curves = plot_pcs(experiment=experiment, animals=animals, kind=kind, save=False, format='png', transparent=False)

# %% [markdown]
# ## Grouped animals

# %%
kind = 'prob_right'
psych_curve_rest = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=None, format='png', transparent=False)  # Rest
psych_curve_saline = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=0, format='png', transparent=False)  # Saline
psych_curve_drug = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=1, format='png', transparent=False)  # Drug (MK-801)
# Out:
# plot_mean_pc took 0.93 seconds to run
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_mean_pc took 0.86 seconds to run
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_mean_pc took 0.91 seconds to run

# %% [markdown]
# # Probability choose REPEAT

# %% [markdown]
# ## Single animals

# %%
# psych_curves = plot_pcs(experiment=experiment, animals=animals, kind=kind, save=False, format='png', transparent=False)

# %% [markdown]
# ## Grouped animals

# %%
kind = 'prob_rep'
psych_curve_rest = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=None, format='png', transparent=False)  # Rest
psych_curve_saline = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=0, format='png', transparent=False)  # Saline
psych_curve_drug = plot_mean_pc(experiment='2AFC_6', animals=animals, save=False, kind=kind, drug=1, format='png', transparent=False)  # Drug (MK-801)
# Out:
# plot_mean_pc took 0.92 seconds to run
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_mean_pc took 0.92 seconds to run
# Animal 022 has 0 ILDs, not 9. Need more trials. Skipping...
# Animal 024 has 0 ILDs, not 9. Need more trials. Skipping...
# plot_mean_pc took 1.02 seconds to run
