# %%
from kernels.psychophysical_kernels import *

# %%
# Magics
# %load_ext autoreload
# %autoreload 2

# %%
# Set parameters
experiment = '2AFC_2'
animal = '333'

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=False, zscore=False,
            control=None, n_mean_frames=None, iterations=1, save=False)
# Out:
# get_pk took 11.71 seconds to run
# plot_pk took 11.95 seconds to run

# %% [markdown]
# # Psychophysical kernels

# %%
# Set parameters
experiment = ['2AFC_6']
animal = None

# # All frames
# plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
#             control=None, n_mean_frames=None, iterations=1, save=False)
# # 5 mean frames
# n_mean_frames = 5
# plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
#             control=None, n_mean_frames=n_mean_frames, iterations=1, save=False)
# # 2 mean frames
# n_mean_frames = 2
# plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
#             control=None, n_mean_frames=n_mean_frames, iterations=1, save=False)

# %% [markdown]
# ## Normal

# %%
plot_pk(experiment=['2AFC_2', '2AFC_3', '2AFC_4'], animal=animal, target_ilds=None, drug=None, residuals=False, zscore=False,
            control=None, n_mean_frames=10, iterations=1, save=False)
# Out:
# 2AFC_2
# /home/alexis/PycharmProjects/glue_sessions/2AFC_2
# Getting kernel of animal 325 (1/8)
# get_pk took 3.00 seconds to run
# Getting kernel of animal 327 (2/8)
# get_pk took 3.90 seconds to run
# Getting kernel of animal 329 (3/8)
# get_pk took 4.68 seconds to run
# Getting kernel of animal 330 (4/8)
# get_pk took 1.99 seconds to run
# Getting kernel of animal 332 (5/8)
# get_pk took 11.93 seconds to run
# Getting kernel of animal 333 (6/8)
# get_pk took 11.63 seconds to run
# Getting kernel of animal 335 (7/8)
# get_pk took 5.83 seconds to run
# Getting kernel of animal 337 (8/8)
# get_pk took 8.88 seconds to run
# 2AFC_3
# /home/alexis/PycharmProjects/glue_sessions/2AFC_3
# Getting kernel of animal 419 (1/6)
# get_pk took 4.46 seconds to run
# Getting kernel of animal 420 (2/6)
# get_pk took 8.36 seconds to run
# Getting kernel of animal 422 (3/6)
# get_pk took 9.28 seconds to run
# Getting kernel of animal 616 (4/6)
# get_pk took 6.30 seconds to run
# Getting kernel of animal 619 (5/6)
# get_pk took 2.90 seconds to run
# Getting kernel of animal 623 (6/6)
# get_pk took 7.31 seconds to run
# 2AFC_4
# /home/alexis/PycharmProjects/glue_sessions/2AFC_4
# Getting kernel of animal 419 (1/6)
# Could not get kernel of animal 419
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/419.csv'
# Getting kernel of animal 420 (2/6)
# Could not get kernel of animal 420
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/420.csv'
# Getting kernel of animal 422 (3/6)
# Could not get kernel of animal 422
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/422.csv'
# Getting kernel of animal 616 (4/6)
# Could not get kernel of animal 616
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/616.csv'
# Getting kernel of animal 619 (5/6)
# Could not get kernel of animal 619
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/619.csv'
# Getting kernel of animal 623 (6/6)
# Could not get kernel of animal 623
# [Errno 2] No such file or directory: '/home/alexis/PycharmProjects/glue_sessions/2AFC_4/623.csv'
# get_mean_pk took 90.47 seconds to run
# plot_pk took 90.51 seconds to run

# %% [markdown]
# ## Saline

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=0, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)
# Out:
# 2AFC_6
# /Users/alexis/PycharmProjects/glue_sessions/2AFC_6
# Getting kernel of animal 014 (1/11)
# Could not get kernel of animal 014
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 016 (2/11)
# Could not get kernel of animal 016
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 017 (3/11)
# Could not get kernel of animal 017
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 018 (4/11)
# Could not get kernel of animal 018
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 019 (5/11)
# Could not get kernel of animal 019
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 020 (6/11)
# Could not get kernel of animal 020
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 021 (7/11)
# Could not get kernel of animal 021
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 022 (8/11)
# Could not get kernel of animal 022
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 023 (9/11)
# Could not get kernel of animal 023
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 024 (10/11)
# Could not get kernel of animal 024
# name 'filter_drug_sessions' is not defined
# Getting kernel of animal 025 (11/11)
# Could not get kernel of animal 025
# name 'filter_drug_sessions' is not defined
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=0, residuals=True, zscore=False,
#       2             control=None, n_mean_frames=None, iterations=10, save=False)
#
# File ~/PycharmProjects/my_fun/my_fun.py:1041, in timer.<locals>.wrapper(*args, **kwargs)
#    1038 @wraps(func)
#    1039 def wrapper(*args, **kwargs):
#    1040     start = time.time()
# -> 1041     result = func(*args, **kwargs)
#    1042     end = time.time()
#    1043     print(f"{func.__name__} took {end - start:.2f} seconds to run")
#
# File ~/PycharmProjects/kernels/psychophysical_kernels.py:371, in plot_pk(experiment, animal, target_ilds, drug, residuals, zscore, control, n_mean_frames, iterations, save)
#     366 @timer
#     367 def plot_pk(experiment='2AFC_6', animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
#     368             control=None, n_mean_frames=None, iterations=1000, save=False):
#     370     if type(experiment) == list:
# --> 371         pk = get_mean_pk(experiments=experiment, animals=None, target_ilds=target_ilds, drug=drug,
#     372                          residuals=residuals, zscore=zscore, control=control, n_mean_frames=n_mean_frames, iterations=iterations)
#     373         title = f'N={len(pk.animal)}, {pk.n_trials} trials'
#     374         filename_prefix = 'mean_'
#
# File ~/PycharmProjects/my_fun/my_fun.py:1041, in timer.<locals>.wrapper(*args, **kwargs)
#    1038 @wraps(func)
#    1039 def wrapper(*args, **kwargs):
#    1040     start = time.time()
# -> 1041     result = func(*args, **kwargs)
#    1042     end = time.time()
#    1043     print(f"{func.__name__} took {end - start:.2f} seconds to run")
#
# File ~/PycharmProjects/kernels/psychophysical_kernels.py:614, in get_mean_pk(experiments, animals, target_ilds, drug, residuals, zscore, control, n_mean_frames, iterations)
#     611     experiments_across_batches.append(experiment)
#     613 n_trials = sum(n_trials_across_animals)
# --> 614 n_frames = pk.n_frames
#     616 # Get mean and sem of the parameters across animals
#     617 params_across_animals = np.array(params_across_animals)
#
# UnboundLocalError: cannot access local variable 'pk' where it is not associated with a value

# %% [markdown]
# ## Drug

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=1, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)

# %% [markdown]
# # History kernels
