# %%
from kernels.pks_test import *

# %%
plot_pk(experiment='2AFC_6', animal='014', target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=1000, save=False)
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                 Choice   No. Observations:                 1288
# Model:                            GLM   Df Residuals:                     1269
# Model Family:                Binomial   Df Model:                           18
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -554.78
# Date:                Tue, 01 Jul 2025   Deviance:                       1109.6
# Time:                        15:30:22   Pearson chi2:                 1.28e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.4079
# Covariance Type:            nonrobust
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0              0.0275      0.001     20.727      0.000       0.025       0.030
# ...
