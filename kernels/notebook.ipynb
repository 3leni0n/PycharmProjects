# %%
from kernels.pks_test import *

# %%
plot_pk(experiment='2AFC_6', animal='014', target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=1000, save=False)
# Out:
# C:\Users\Usuario\PycharmProjects\kernels\kernels_tools.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_frame.iloc[0] = 0  # Set to 0 to avoid artifact of net ILD 70 having 0 weight
# C:\Users\Usuario\PycharmProjects\kernels\kernels_tools.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_frame.iloc[-1] = 0  # Set to 0 to avoid artifact of net ILD 70 having 0 weight
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Choice   No. Observations:                 2144
# Model:                            GLM   Df Residuals:                     2120
# Model Family:                Binomial   Df Model:                           23
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -992.18
# Date:                Tue, 08 Jul 2025   Deviance:                       1984.4
# Time:                        18:04:12   Pearson chi2:                 2.17e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.3691
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0                   0          0        nan        nan           0           0
# 1              0.0059      0.077      0.077      0.938      -0.144       0.156
# 2              0.1227      0.079      1.554      0.120      -0.032       0.277
# 3              0.0097      0.069      0.140      0.889      -0.126       0.145
# 4             -0.0381      0.073     -0.520      0.603      -0.182       0.106
# 5             -0.0510      0.076     -0.674      0.501      -0.199       0.097
# 6             -0.0850      0.075     -1.131      0.258      -0.232       0.062
# 7             -0.0401      0.072     -0.559      0.576      -0.181       0.100
# 8             -0.0583      0.076     -0.769      0.442      -0.207       0.090
# 9             -0.0072      0.081     -0.089      0.929      -0.165       0.151
# 10             0.0530      0.073      0.725      0.468      -0.090       0.196
# 0             -0.1836      0.173     -1.064      0.287      -0.522       0.155
# 1              0.1094      0.175      0.625      0.532      -0.233       0.452
# 2             -0.2982      0.159     -1.875      0.061      -0.610       0.014
# 3             -0.1182      0.155     -0.763      0.445      -0.422       0.185
# 4             -0.0933      0.163     -0.572      0.567      -0.413       0.226
# 5              0.3324      0.167      1.987      0.047       0.005       0.660
# 6              0.2158      0.174      1.241      0.215      -0.125       0.557
# 7              0.4702      0.173      2.720      0.007       0.131       0.809
# 8              0.8919      0.510      1.750      0.080      -0.107       1.891
# 9             -0.6241      0.230     -2.710      0.007      -1.075      -0.173
# 2              0.4392      0.206      2.133      0.033       0.036       0.843
# 4              0.2972      0.175      1.698      0.090      -0.046       0.640
# 8              0.9678      0.223      4.348      0.000       0.532       1.404
# 70             1.7485      0.069     25.499      0.000       1.614       1.883
# ==============================================================================
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# get_pk took 49.88 seconds to run
