# %%
from kernels.psychophysical_kernels import *

# %%
# Magics
# %load_ext autoreload
# %autoreload 2

# %%
# Set parameters
experiment = ['2AFC_6']
animal = None

# %% [markdown]
# # Psychophysical kernels

# %% [markdown]
# ## Normal

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=10, iterations=1, save=False)

# %% [markdown]
# ## Saline

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=0, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)

# %% [markdown]
# ## Drug

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=1, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)

# %% [markdown]
# # History kernels

# %%
# Set parameters
# experiment = ['2AFC_2', '2AFC_3']
experiment = ['2AFC_2']
animal = None

# %%
# Engagement test
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=1, save=False)
# Out:
# 2AFC_2
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_2
# Getting kernel of animal 325 (1/8)
# get_pk took 0.61 seconds to run
# Getting kernel of animal 327 (2/8)
# get_pk took 0.63 seconds to run
# Getting kernel of animal 329 (3/8)
# Could not get kernel of animal 329
# [Errno 2] No such file or directory: 'C:\\Users\\Usuario\\PycharmProjects\\intersession\\2AFC_2\\329_intersession.csv'
# Getting kernel of animal 330 (4/8)
# get_pk took 0.42 seconds to run
# Getting kernel of animal 332 (5/8)
# get_pk took 3.09 seconds to run
# Getting kernel of animal 333 (6/8)
# get_pk took 6.69 seconds to run
# Getting kernel of animal 335 (7/8)
# Could not get kernel of animal 335
# [Errno 2] No such file or directory: 'C:\\Users\\Usuario\\PycharmProjects\\intersession\\2AFC_2\\335_intersession.csv'
# Getting kernel of animal 337 (8/8)
# Could not get kernel of animal 337
# [Errno 2] No such file or directory: 'C:\\Users\\Usuario\\PycharmProjects\\intersession\\2AFC_2\\337_intersession.csv'
# get_mean_pk took 11.77 seconds to run
# plot_pk took 11.83 seconds to run
