# %%
from kernels.psychophysical_kernels import *

# %%
# Magics
# %load_ext autoreload
# %autoreload 2

# %%
# Set parameters
experiment = ['2AFC_6']
animal = None

# %% [markdown]
# # Normal

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=10, iterations=1000, save=False)
# Out:
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# get_pk took 70.87 seconds to run
# Getting kernel of animal 016 (2/11)
# get_pk took 64.39 seconds to run
# Getting kernel of animal 017 (3/11)
# get_pk took 80.17 seconds to run
# Getting kernel of animal 018 (4/11)
# get_pk took 41.70 seconds to run
# Getting kernel of animal 019 (5/11)
# get_pk took 73.44 seconds to run
# Getting kernel of animal 020 (6/11)
# get_pk took 30.16 seconds to run
# Getting kernel of animal 021 (7/11)
# get_pk took 34.03 seconds to run
# Getting kernel of animal 022 (8/11)
# get_pk took 62.49 seconds to run
# Getting kernel of animal 023 (9/11)
# get_pk took 33.34 seconds to run
# Getting kernel of animal 024 (10/11)
# get_pk took 44.21 seconds to run
# Getting kernel of animal 025 (11/11)
# get_pk took 28.04 seconds to run
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# get_mean_pk took 563.38 seconds to run
# plot_pk took 563.43 seconds to run

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=10, iterations=1, save=False)
# Out:
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# get_pk took 0.62 seconds to run
# Getting kernel of animal 016 (2/11)
# get_pk took 0.54 seconds to run
# Getting kernel of animal 017 (3/11)
# get_pk took 0.57 seconds to run
# Getting kernel of animal 018 (4/11)
# get_pk took 0.47 seconds to run
# Getting kernel of animal 019 (5/11)
# get_pk took 0.87 seconds to run
# Getting kernel of animal 020 (6/11)
# Could not get kernel of animal 020
# zero-size array to reduction operation maximum which has no identity
# Getting kernel of animal 021 (7/11)
# get_pk took 0.47 seconds to run
# Getting kernel of animal 022 (8/11)
# get_pk took 0.47 seconds to run
# Getting kernel of animal 023 (9/11)
# get_pk took 0.55 seconds to run
# Getting kernel of animal 024 (10/11)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# get_pk took 0.31 seconds to run
# Getting kernel of animal 025 (11/11)
# Could not get kernel of animal 025
# zero-size array to reduction operation maximum which has no identity
# get_mean_pk took 5.24 seconds to run
# plot_pk took 5.27 seconds to run

# %% [markdown]
# # Saline

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=0, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)
# Out:
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# get_pk took 1.54 seconds to run
# Getting kernel of animal 016 (2/11)
# get_pk took 1.71 seconds to run
# Getting kernel of animal 017 (3/11)
# get_pk took 1.81 seconds to run
# Getting kernel of animal 018 (4/11)
# get_pk took 1.14 seconds to run
# Getting kernel of animal 019 (5/11)
# get_pk took 1.34 seconds to run
# Getting kernel of animal 020 (6/11)
# get_pk took 1.56 seconds to run
# Getting kernel of animal 021 (7/11)
# Could not get kernel of animal 021
# zero-size array to reduction operation maximum which has no identity
# Getting kernel of animal 022 (8/11)
# Could not get kernel of animal 022
# zero-size array to reduction operation maximum which has no identity
# Getting kernel of animal 023 (9/11)
# get_pk took 1.44 seconds to run
# Getting kernel of animal 024 (10/11)
# get_pk took 1.64 seconds to run
# Getting kernel of animal 025 (11/11)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Could not get kernel of animal 025
# zero-size array to reduction operation maximum which has no identity
# get_mean_pk took 15.99 seconds to run
# plot_pk took 16.01 seconds to run

# %% [markdown]
# # Drug

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=1, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)
# Out:
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# get_pk took 1.56 seconds to run
# Getting kernel of animal 016 (2/11)
# get_pk took 1.69 seconds to run
# Getting kernel of animal 017 (3/11)
# get_pk took 1.78 seconds to run
# Getting kernel of animal 018 (4/11)
# get_pk took 1.12 seconds to run
# Getting kernel of animal 019 (5/11)
# get_pk took 1.35 seconds to run
# Getting kernel of animal 020 (6/11)
# get_pk took 1.55 seconds to run
# Getting kernel of animal 021 (7/11)
# Could not get kernel of animal 021
# zero-size array to reduction operation maximum which has no identity
# Getting kernel of animal 022 (8/11)
# Could not get kernel of animal 022
# zero-size array to reduction operation maximum which has no identity
# Getting kernel of animal 023 (9/11)
# get_pk took 1.51 seconds to run
# Getting kernel of animal 024 (10/11)
# get_pk took 1.53 seconds to run
# Getting kernel of animal 025 (11/11)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Could not get kernel of animal 025
# zero-size array to reduction operation maximum which has no identity
# get_mean_pk took 15.96 seconds to run
# plot_pk took 15.99 seconds to run
