# %%
from kernels.psychophysical_kernels import *

# %%
# Magics
# %load_ext autoreload
# %autoreload 2

# %%
# Set parameters
experiment = ['2AFC_6']
animal = None

# %% [markdown]
# # Psychophysical kernels

# %%
# All frames
plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=1, save=False)
# 5 mean frames
n_mean_frames = 5
plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=n_mean_frames, iterations=1, save=False)
# 2 mean frames
n_mean_frames = 2
plot_drug_pk(experiment=experiment, animal=None, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=n_mean_frames, iterations=1, save=False)
# Out:
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.84 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.07 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.07 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.19 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.33 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.18 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.96 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.92 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.78 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.83 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.68 seconds to run
# get_mean_pk took 19.84 seconds to run
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.74 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.91 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.01 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.18 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.25 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.10 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.91 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.91 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.67 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.89 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.69 seconds to run
# get_mean_pk took 19.28 seconds to run
# plot_drug_pk took 39.14 seconds to run
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.73 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.95 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.08 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.20 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.30 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.15 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.92 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.97 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.69 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.87 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.69 seconds to run
# get_mean_pk took 19.55 seconds to run
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.74 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.92 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.02 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.13 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.29 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.15 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.91 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.89 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.70 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.88 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.68 seconds to run
# get_mean_pk took 19.30 seconds to run
# plot_drug_pk took 38.87 seconds to run
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.77 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.93 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.01 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.18 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.30 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.13 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.02 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.94 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.67 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.85 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.67 seconds to run
# get_mean_pk took 19.47 seconds to run
# 2AFC_6
# C:\Users\Usuario\PycharmProjects\glue_sessions\2AFC_6
# Getting kernel of animal 014 (1/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.76 seconds to run
# Getting kernel of animal 016 (2/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.95 seconds to run
# Getting kernel of animal 017 (3/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.14 seconds to run
# Getting kernel of animal 018 (4/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.16 seconds to run
# Getting kernel of animal 019 (5/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.45 seconds to run
# Getting kernel of animal 020 (6/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 2.12 seconds to run
# Getting kernel of animal 021 (7/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.90 seconds to run
# Getting kernel of animal 022 (8/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.88 seconds to run
# Getting kernel of animal 023 (9/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.66 seconds to run
# Getting kernel of animal 024 (10/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.86 seconds to run
# Getting kernel of animal 025 (11/11)
# C:\Users\Usuario\PycharmProjects\create_sounds\sounds_6.1.csv
# get_pk took 1.68 seconds to run
# get_mean_pk took 19.56 seconds to run
# plot_drug_pk took 39.05 seconds to run

# %% [markdown]
# ## Normal

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=10, iterations=1, save=False)

# %% [markdown]
# ## Saline

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=0, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)

# %% [markdown]
# ## Drug

# %%
plot_pk(experiment=experiment, animal=animal, target_ilds=None, drug=1, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=10, save=False)

# %% [markdown]
# # History kernels
