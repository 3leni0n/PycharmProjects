# %%
from kernels.pks_test import *

# %%
plot_pk(experiment='2AFC_6', animal='014', target_ilds=None, drug=None, residuals=True, zscore=False,
            control=None, n_mean_frames=None, iterations=1000, save=False)
# Out:
# C:\Users\Usuario\PycharmProjects\kernels\kernels_tools.py:125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_frame.iloc[0] = 0  # Set to 0 to avoid artifact of net ILD 70 having 0 weight
# C:\Users\Usuario\PycharmProjects\kernels\kernels_tools.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_frame.iloc[-1] = 0  # Set to 0 to avoid artifact of net ILD 70 having 0 weight
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 Choice   No. Observations:                 1967
# Model:                            GLM   Df Residuals:                     1945
# Model Family:                Binomial   Df Model:                           21
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -900.23
# Date:                Wed, 02 Jul 2025   Deviance:                       1800.5
# Time:                        15:12:38   Pearson chi2:                 1.99e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.3752
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 0                   0          0        nan        nan           0           0
# 1              0.0019      0.077      0.025      0.980      -0.149       0.153
# 2              0.1129      0.080      1.418      0.156      -0.043       0.269
# 3              0.0090      0.070      0.129      0.898      -0.128       0.146
# 4             -0.0344      0.075     -0.461      0.645      -0.181       0.112
# 5             -0.0360      0.077     -0.470      0.639      -0.186       0.114
# 6             -0.1102      0.076     -1.447      0.148      -0.260       0.039
# 7             -0.0388      0.072     -0.536      0.592      -0.181       0.103
# 8             -0.0493      0.076     -0.644      0.520      -0.199       0.101
# 9              0.0040      0.081      0.049      0.961      -0.155       0.163
# 10             0.0546      0.073      0.745      0.456      -0.089       0.198
# 0             -0.1892      0.175     -1.082      0.279      -0.532       0.153
# 1              0.1172      0.177      0.661      0.509      -0.230       0.465
# 2             -0.3061      0.161     -1.898      0.058      -0.622       0.010
# 3             -0.1209      0.157     -0.769      0.442      -0.429       0.187
# 4             -0.1014      0.165     -0.613      0.540      -0.425       0.223
# 5              0.3365      0.169      1.991      0.046       0.005       0.668
# 6              0.2182      0.176      1.240      0.215      -0.127       0.563
# 7              0.4833      0.175      2.759      0.006       0.140       0.827
# 2              0.4219      0.207      2.041      0.041       0.017       0.827
# 4              0.2621      0.176      1.487      0.137      -0.083       0.608
# 8              0.9967      0.225      4.426      0.000       0.555       1.438
# 70             1.8014      0.073     24.596      0.000       1.658       1.945
# ==============================================================================
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# get_pk took 23.06 seconds to run
