# %% [markdown]
# # Random and low-rank networks

# %% [markdown]
# ### Implement dynamics

# %%
# %matplotlib inline
import numpy as np
import numpy as numpy
import scipy.integrate
from matplotlib import pyplot as plt
from numpy import random as rd

def F(x):
    return np.tanh(x)

def IntegrateAuto(X, t):
    dXdT=-X+np.dot(J, F(X))
    return dXdT

def LookActAuto(_t,_x0):
    _x=scipy.integrate.odeint(IntegrateAuto,_x0,_t)
    return _x

# %% [markdown]
# ### TODO: Define NxN matrix $J$ of random Gaussian elements, mean 0, variance $g/\sqrt{N}$

# %% [markdown]
# ### TODO: show that 0 is a fixed point, with Jacobian $J$
# ### Plot eigenvalues of $J$

# %% [markdown]
# ### TODO: what happens as $g$ is increased?
# ### Plot dynamics $x(t)$ for different values of $g$

# %% [markdown]
# ### Define correlated Gaussian vectors from uncorrelated vectors

# %%
sigma=1.801
rho=1.1

x=np.random.normal(0, 1.0, (N))
y=np.random.normal(0, 1.0, (N))
z=np.random.normal(0, 1.0, (N))

m=np.sqrt(sigma*sigma-rho)*x+np.sqrt(rho)*z
n=np.sqrt(sigma*sigma-rho)*y+np.sqrt(rho)*z

# %% [markdown]
# ### TODO: compute overalps between m and n, and the variance, covariance of their entries

# %% [markdown]
# ### Defining a unit rank matrix from vectors m and n

# %%
P=np.outer(m,n)/N

# %% [markdown]
# ### TODO: Display the matrix P

# %% [markdown]
# ### TODO: Determine  (analytically) the eigenvectors and eigenvalues of P

# %% [markdown]
# ### TODO: Add the unit rank matrix P  to the random connectivity

# %% [markdown]
# ### TODO: Determine (numerically) the eigenspectrum of the obtained matrix. How can it be described?

# %% [markdown]
# ### TODO: show that 0 is still a fixed point, and determine its stability

# %% [markdown]
# ### TODO: Explore the range of possible dynamics based on the stability analysis

# %% [markdown]
# ### Todo: sketch a phase diagram of dynamics in the g-rho plane
