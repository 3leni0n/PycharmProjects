# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.special import erfcx
from ana_rtd_comp import ana_rtd
from ana_acc_comp import ana_acc
import pandas as pd
from scipy.special import erfc
import seaborn as sns
import ast
from pybads import BADS
import numpy as np
import matplotlib.pyplot as plt
from model_tach_shift_v5 import model_tach_shift

tt=np.arange(0,1000, 1)
compressive_power= 0.2
a_tied= 20
T0= 2
ndt=70
v=0.12
a=60
abl=20
ild=2
t_fix= 400
w_tse= .75
tse = ndt*w_tse
Delta = -tse+10

x = [compressive_power, a_tied, T0, ndt, v, a, w_tse, Delta]

# model = model_tach_shift(ABL=abl,ILD=ild,t_fix=t_fix)
# initialize the model
model = model_tach_shift(RT=tt,ABL=abl*np.ones_like(tt),ILD=ild*np.ones_like(tt),t_fix=t_fix*np.ones_like(tt),out=1.0*np.ones_like(tt))
model.set_params(x)
model.print_params()


logL_corr, logL_err = model.log_likelihood_both()
print(np.sum(logL_corr)) 
print(np.sum(logL_err))

logL = model.log_likelihood()
print(np.sum(logL))
# Out:
# [ 0.2 20.   2.  70. ] [ 0.12 60.  ] 0.75 -42.5
# -10588.849299419318
# -11254.149960868544
# -10588.849299419318

# %%
df= pd.read_csv('out_SD.csv')
df['RT'] = df['timed_fix']-df['intended_fix']
df['RT_ms']= df['RT']*1000
df['intended_fix_ms']= df['intended_fix']*1000 
df['time_to_CNP_c'] = df['time_to_CNP'].apply(lambda x: 1 if x < 0.002 else 0)
df['timed_fix_ms']= df['timed_fix']*1000
df['|ILD|']=df['ILD'].abs()
df = df[
    (df['ABL'].isin([20, 40, 60])) &
    (df['ILD'].isin([-1, -2, -4, -8, 1, 2, 4, 8])) &
    (df['abort_event'].isin([-1,-2,3,4])) &
    (df['time_to_CNP_c'] == 0)&
    (df['max_samplingTime'].isin([6]))&
    (df['timed_fix_ms']>200)
    ]

# %%
x = [compressive_power, a_tied, T0, ndt, v, a, w_tse, Delta]
rt_vect=np.array(df['RT_ms'])
abl_vect=np.array(df['ABL'])
ild_vect=np.array(df['ILD'])
fix_vect=np.array(df['intended_fix_ms'])
out_vect=np.array(df['success'])
# model = model_tach_shift(ABL=abl,ILD=ild,t_fix=t_fix)
# initialize the model
model = model_tach_shift(RT=rt_vect,ABL=abl_vect,ILD=ild_vect,t_fix=fix_vect, out=out_vect)
model.set_params(x)
model.print_params()


logL_corr, logL_err = model.log_likelihood_both()
print(np.sum(logL_corr)) 
print(np.sum(logL_err))

logL = model.log_likelihood()
print(np.sum(logL))
# Out:
# [ 0.2 20.   2.  70. ] [ 0.12 60.  ] 0.75 -42.5
# -346721.4157752501
# -400340.6077725313
# -353729.81435871153

# %%
def total_log_likelihood(data, params):
    rt_vect=np.array(data['RT_ms'])
    abl_vect=np.array(data['ABL'])
    ild_vect=np.array(data['|ILD|'])
    fix_vect=np.array(data['intended_fix_ms'])
    out_vect=np.array(data['success'])
    model = model_tach_shift(RT=rt_vect,ABL=abl_vect,ILD=ild_vect,t_fix=fix_vect, out=out_vect)
    model.set_params(params)
    logL = model.log_likelihood()
    return np.sum(logL)

# %%
def objective_function(params, data):
    """ 
    Compute the negative log-likelihood for the DDM parameters.
    
    :param params: array of model parameters [v, a, x1, x2, x3, x4]
    :param data: DataFrame with the experimental data
    :return: Negative log-likelihood

    """ # Assuming x includes 4 parameters
    # Calculate the total log likelihood using the defined function
    # BADS minimizes the function, so return negative log likelihood
    return -total_log_likelihood(data, params)
#create a suitable function for bads

def objective_fun_forbads(params):
    data= df_animal
    return objective_function(params, data)

# x = [compressive_power, a_tied, T0, ndt, v, a, w_tse, Delta]
initial_param_sets = [
    [0.1, 35, 1, 40,0.08,20,0.2,-30],
    [0.2, 20, 0.5, 50,0.06,30,0.3,-20],
    [0.25, 30, 0.75,60, 0.1, 50,0.1,-10]
]

#              lambda a_tied  T0    ndt  v     a_pa  w_tse  Delta
lower_bounds = [0.03, 10,     0.05, 0,   0,    10,   0,     -80]  # Hard lower bounds
upper_bounds = [0.5,  80,     4,    100, 1,    100,  1,     10]  # Hard upper bounds
plausible_lb = [0.05, 15,     0.1,  10,  0.01, 15,   0.01,  -70]  # Plausible lower bounds
plausible_ub = [0.3,  60,     3,    90,  0.8,  90,   0.9,   0]  # Plausible upper bounds

# Run optimization for each animal
all_results = []
animal_value= df['animal'].unique()
for idx, animal in enumerate(animal_value):
    print(animal)
    best_result = None
    df_animal = df[(df['animal'] == animal)&(df['max_samplingTime']==6)]
    row_count = len(df_animal)
    for i, initial_params in enumerate(initial_param_sets):
        print(f"Starting optimization with initial params: {initial_params}")
        bads = BADS(objective_fun_forbads, initial_params, lower_bounds, upper_bounds, plausible_lb, plausible_ub)
        optimize_result = bads.optimize()
        result_details = {
            'animal': animal,
            'initial_params': str(initial_params),
            'optimized_params': str(optimize_result.x),
            'result_fun': optimize_result.fval,
            'row_count': row_count,
            'is_best': 0  # Default to 0, will update later if it's the best
        }
        print(f"Optimization result: {optimize_result.x}, {optimize_result.fval}")
        all_results.append(result_details)

        # Update the best result if it's the first run or better than the previous best
        if best_result is None or optimize_result.fval < best_result.fval:
            best_result = optimize_result
            best_params = initial_params

    # Update the best result indicator for the best optimization run
    for result in all_results:
        if result['animal'] == animal and result['initial_params'] == str(best_params):
            result['is_best'] = 1

# Convert all_results to a DataFrame
results_df = pd.DataFrame(all_results)
results_df.to_csv('tied_pa_accu_fit_delta_real_right.csv', index=False)
# Out:
# 48
# Starting optimization with initial params: [0.1, 35, 1, 40, 0.08, 20, 0.2, -30]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         50348.7               1                                 Uncertainty test
#      0          18         46150.9               1         Initial mesh            Initial points
#      0          27           41357               1       Successful poll           Train
#      1          33         41214.9               1     Successful search (ES-wcm)
#      1          42         41126.7               1     Successful search (ES-wcm)
#      1          43         41122.9               1     Successful search (ES-wcm)
#      1          53         41104.9               1       Successful poll           Train
#      2          56         40904.6               1     Successful search (ES-ell)
#      2          60         40779.7               1     Successful search (ES-ell)
#      2          65         40678.4               1     Successful search (ES-ell)
#      2          67         40663.5               1     Successful search (ES-ell)
#      2          68         40612.7               1     Successful search (ES-ell)
#      2          72         40535.3               1     Successful search (ES-ell)
#      2          74         40520.7               1     Successful search (ES-ell)
#      2          76         40512.4               1     Successful search (ES-ell)
#      2          80         40490.5               1     Successful search (ES-ell)
#      2          85         40458.4               1     Successful search (ES-ell)
#      2          89         40422.6               1     Successful search (ES-ell)
#      2          91         40418.9               1     Successful search (ES-ell)
#      2          93         40396.2               1     Successful search (ES-ell)
#      2          94         40386.7               1     Successful search (ES-ell)
#      2          98         40377.5               1     Successful search (ES-ell)
#      2         106         40360.7               1     Successful search (ES-ell)
#      2         109         40355.9               1     Successful search (ES-ell)
#      2         114         40349.2               1     Successful search (ES-ell)
#      2         116         40347.8               1     Successful search (ES-wcm)
#      2         120         40343.5               1     Successful search (ES-ell)
#      2         123         40338.8               1     Successful search (ES-wcm)
#      2         127         40333.8               1     Successful search (ES-wcm)
#      2         131         40325.3               1     Successful search (ES-wcm)
#      2         141           40312               1     Successful search (ES-wcm)
#      2         148         40304.4               1     Successful search (ES-ell)
#      2         149         40301.2               1     Successful search (ES-ell)
#      2         153         40296.8               1     Successful search (ES-ell)
#      2         156         40295.4               1     Successful search (ES-ell)
#      2         163           40289               1     Successful search (ES-ell)
#      2         164         40283.4               1     Successful search (ES-wcm)
#      2         170         40283.2               1     Incremental search (ES-wcm)
#      2         183         40283.2             0.5         Refine grid
#      3         187         40274.5             0.5     Successful search (ES-wcm)
#      3         195         40273.3             0.5     Successful search (ES-wcm)
#      3         197         40266.8             0.5     Successful search (ES-wcm)
#      3         198         40261.7             0.5     Successful search (ES-wcm)
#      3         202         40257.7             0.5     Successful search (ES-wcm)
#      3         205         40257.5             0.5     Incremental search (ES-wcm)
#      3         212         40256.7             0.5     Successful search (ES-wcm)
#      3         217         40255.9             0.5     Successful search (ES-wcm)
#      3         219         40255.1             0.5     Successful search (ES-wcm)
#      3         221         40254.5             0.5     Successful search (ES-wcm)
#      3         228         40254.5             0.5     Incremental search (ES-ell)
#      3         243         40254.5            0.25         Refine grid
#      4         246         40254.4            0.25     Incremental search (ES-wcm)
#      4         248         40254.4            0.25     Incremental search (ES-wcm)
#      4         264         40254.4           0.125         Refine grid             Train
#      5         270         40254.4           0.125     Successful search (ES-wcm)
#      5         294         40254.4          0.0625         Refine grid
#      6         316         40254.4         0.03125         Refine grid
#      7         321         40254.4         0.03125     Incremental search (ES-wcm)
#      7         338         40254.4        0.015625         Refine grid             Train
#      8         340         40254.4        0.015625     Successful search (ES-wcm)
#      8         351         40254.4        0.015625     Incremental search (ES-ell)
#      8         368         40254.4       0.0078125         Refine grid
#      9         371         40254.4       0.0078125     Successful search (ES-ell)
#      9         376         40254.4       0.0078125     Successful search (ES-wcm)
#      9         377         40254.4       0.0078125     Successful search (ES-ell)
#      9         406         40254.4      0.00390625         Refine grid             Train
#     10         409         40254.4      0.00390625     Incremental search (ES-wcm)
#     10         414         40254.4      0.00390625     Incremental search (ES-ell)
#     10         419         40254.2       0.0078125       Successful poll           Train
#     11         441         40254.2      0.00390625         Refine grid             Train
#     12         449         40254.2      0.00390625     Successful search (ES-ell)
#     12         471         40254.2      0.00195312         Refine grid             Train
#     13         476         40254.2      0.00195312     Successful search (ES-ell)
#     13         502         40254.2     0.000976562         Refine grid
#     14         525         40254.2     0.000488281         Refine grid
#     15         548         40254.2     0.000244141         Refine grid             Train
#     16         555         40254.2     0.000244141     Incremental search (ES-ell)
#     16         571         40254.2      0.00012207         Refine grid             Train
#     17         594         40254.2     6.10352e-05         Refine grid             Train
#     18         598         40254.2     6.10352e-05     Incremental search (ES-ell)
#     18         617         40254.2     3.05176e-05         Refine grid
#     19         619         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         623         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         640         40254.2     7.62939e-06         Refine grid
#     20         641         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         642         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         645         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         646         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         648         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         663         40254.2     1.90735e-06         Refine grid             Train
#     21         664         40254.2     1.90735e-06     Incremental search (ES-ell)
#     21         666         40254.2     1.90735e-06     Incremental search (ES-ell)
#     21         671         40254.2     1.90735e-06     Incremental search (ES-ell)
#     21         686         40254.2     4.76837e-07         Refine grid
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 40254.19063047113
#
# Optimization result: [ 0.1758984  27.79681811  1.49772822 73.67598762  0.11032181 79.86484422
#   1.          9.87827083], 40254.19063047113
# Starting optimization with initial params: [0.2, 20, 0.5, 50, 0.06, 30, 0.3, -20]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         66399.9               1                                 Uncertainty test
#      0          18         46150.9               1         Initial mesh            Initial points
#      0          19           41357               1       Successful poll           Train
#      1          22         41287.1               1     Successful search (ES-ell)
#      1          27         41234.2               1     Successful search (ES-ell)
#      1          31         41050.6               1     Successful search (ES-wcm)
#      1          42         41026.6               1     Successful search (ES-wcm)
#      1          50         40953.6               1     Successful search (ES-wcm)
#      1          56           40939               1     Successful search (ES-wcm)
#      1          64         40717.9               1     Successful search (ES-wcm)
#      1          65           40597               1     Successful search (ES-wcm)
#      1          73         40526.5               1     Successful search (ES-wcm)
#      1          81         40452.8               1     Successful search (ES-wcm)
#      1          82           40407               1     Successful search (ES-wcm)
#      1          88         40365.2               1     Successful search (ES-ell)
#      1          95         40341.8               1     Successful search (ES-ell)
#      1          99         40336.6               1     Successful search (ES-ell)
#      1         103           40330               1     Successful search (ES-ell)
#      1         107         40312.2               1     Successful search (ES-ell)
#      1         111         40306.6               1     Successful search (ES-ell)
#      1         119         40302.7               1     Successful search (ES-wcm)
#      1         123         40296.4               1     Successful search (ES-ell)
#      1         125         40290.4               1     Successful search (ES-ell)
#      1         128         40290.4               1     Incremental search (ES-ell)
#      1         133         40288.5               1     Successful search (ES-ell)
#      1         134         40287.5               1     Incremental search (ES-ell)
#      1         139         40286.2               1     Successful search (ES-ell)
#      1         142         40282.5               1     Successful search (ES-ell)
#      1         145         40281.2               1     Successful search (ES-ell)
#      1         147         40279.9               1     Successful search (ES-ell)
#      1         149           40279               1     Incremental search (ES-ell)
#      1         165           40279             0.5         Refine grid             Train
#      2         169         40276.9             0.5     Successful search (ES-ell)
#      2         171         40275.5             0.5     Successful search (ES-ell)
#      2         172         40274.7             0.5     Successful search (ES-ell)
#      2         179           40270             0.5     Successful search (ES-ell)
#      2         181         40263.2             0.5     Successful search (ES-wcm)
#      2         201         40263.2            0.25         Refine grid             Train
#      3         205         40261.1            0.25     Successful search (ES-wcm)
#      3         209         40259.5            0.25     Successful search (ES-wcm)
#      3         213         40258.5            0.25     Successful search (ES-ell)
#      3         216         40258.3            0.25     Successful search (ES-ell)
#      3         221         40257.3            0.25     Successful search (ES-ell)
#      3         223         40257.2            0.25     Incremental search (ES-ell)
#      3         225         40256.9            0.25     Successful search (ES-ell)
#      3         228         40256.8            0.25     Incremental search (ES-ell)
#      3         229         40256.4            0.25     Successful search (ES-ell)
#      3         235         40256.1            0.25     Successful search (ES-ell)
#      3         238         40256.1            0.25     Incremental search (ES-ell)
#      3         240         40255.8            0.25     Successful search (ES-ell)
#      3         243         40255.8            0.25     Incremental search (ES-ell)
#      3         248         40255.6            0.25     Successful search (ES-ell)
#      3         250         40255.3            0.25     Successful search (ES-ell)
#      3         255         40255.3            0.25     Incremental search (ES-ell)
#      3         261           40255            0.25     Successful search (ES-ell)
#      3         264         40254.7            0.25     Successful search (ES-ell)
#      3         267         40254.7            0.25     Incremental search (ES-ell)
#      3         270         40254.7            0.25     Incremental search (ES-ell)
#      3         273         40254.6            0.25     Incremental search (ES-ell)
#      3         286         40254.6           0.125         Refine grid
#      4         288         40254.5           0.125     Successful search (ES-ell)
#      4         289         40254.4           0.125     Incremental search (ES-ell)
#      4         292         40254.4           0.125     Incremental search (ES-ell)
#      4         296         40254.4           0.125     Incremental search (ES-wcm)
#      4         302         40254.4           0.125     Incremental search (ES-wcm)
#      4         316         40254.4          0.0625         Refine grid             Train
#      5         338         40254.4         0.03125         Refine grid             Train
#      6         343         40254.4         0.03125     Incremental search (ES-ell)
#      6         360         40254.4        0.015625         Refine grid             Train
#      7         362         40254.4        0.015625     Successful search (ES-wcm)
#      7         364         40254.4        0.015625     Incremental search (ES-wcm)
#      7         366         40254.4        0.015625     Successful search (ES-wcm)
#      7         371         40254.4        0.015625     Incremental search (ES-wcm)
#      7         376         40254.4        0.015625     Incremental search (ES-wcm)
#      7         390         40254.4       0.0078125         Refine grid
#      8         392         40254.4       0.0078125     Incremental search (ES-wcm)
#      8         398         40254.4       0.0078125     Incremental search (ES-ell)
#      8         412         40254.4      0.00390625         Refine grid
#      9         413         40254.4      0.00390625     Incremental search (ES-wcm)
#      9         416         40254.4      0.00390625     Incremental search (ES-wcm)
#      9         432         40254.2       0.0078125       Successful poll           Train
#     10         454         40254.2      0.00390625         Refine grid             Train
#     11         458         40254.2      0.00390625     Successful search (ES-wcm)
#     11         484         40254.2      0.00195312         Refine grid             Train
#     12         492         40254.2      0.00195312     Successful search (ES-wcm)
#     12         515         40254.2     0.000976562         Refine grid
#     13         538         40254.2     0.000488281         Refine grid             Train
#     14         561         40254.2     0.000244141         Refine grid             Train
#     15         584         40254.2     6.10352e-05         Refine grid             Train
#     16         607         40254.2      0.00012207       Successful poll           Train
#     17         630         40254.2     6.10352e-05         Refine grid             Train
#     18         634         40254.2     6.10352e-05     Incremental search (ES-ell)
#     18         653         40254.2     3.05176e-05         Refine grid
#     19         660         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         661         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         677         40254.2     7.62939e-06         Refine grid
#     20         680         40254.2     7.62939e-06     Incremental search (ES-wcm)
#     20         684         40254.2     7.62939e-06     Incremental search (ES-wcm)
#     20         685         40254.2     7.62939e-06     Incremental search (ES-wcm)
#     20         700         40254.2     1.90735e-06         Refine grid
#     21         704         40254.2     1.90735e-06     Incremental search (ES-ell)
#     21         707         40254.2     1.90735e-06     Incremental search (ES-wcm)
#     21         708         40254.2     1.90735e-06     Incremental search (ES-wcm)
#     21         724         40254.2     4.76837e-07         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 40254.18845371509
#
# Optimization result: [ 0.17506358 27.94198519  1.47567082 73.69463705  0.11028523 79.85043257
#   0.9999973   9.8781939 ], 40254.18845371509
# Starting optimization with initial params: [0.25, 30, 0.75, 60, 0.1, 50, 0.1, -10]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         52301.7               1                                 Uncertainty test
#      0          18         46150.9               1         Initial mesh            Initial points
#      0          19           41357               1       Successful poll           Train
#      1          36           40754               1       Successful poll           Train
#      2          41         40723.3               1     Successful search (ES-ell)
#      2          52           40713               1     Successful search (ES-ell)
#      2          70           40713             0.5         Refine grid             Train
#      3          72         40606.4             0.5     Successful search (ES-ell)
#      3          73         40474.1             0.5     Successful search (ES-wcm)
#      3          80         40408.1             0.5     Successful search (ES-wcm)
#      3          84         40396.7             0.5     Successful search (ES-wcm)
#      3          92         40390.4             0.5     Successful search (ES-ell)
#      3          94         40386.4             0.5     Successful search (ES-wcm)
#      3          99         40380.3             0.5     Successful search (ES-wcm)
#      3         101         40376.8             0.5     Successful search (ES-wcm)
#      3         106           40375             0.5     Successful search (ES-wcm)
#      3         108         40371.2             0.5     Successful search (ES-wcm)
#      3         111         40366.6             0.5     Successful search (ES-ell)
#      3         117         40362.5             0.5     Successful search (ES-ell)
#      3         120         40358.9             0.5     Successful search (ES-ell)
#      3         125         40356.7             0.5     Successful search (ES-ell)
#      3         129         40354.2             0.5     Successful search (ES-ell)
#      3         131         40348.8             0.5     Successful search (ES-wcm)
#      3         133         40348.2             0.5     Successful search (ES-wcm)
#      3         139           40340             0.5     Successful search (ES-wcm)
#      3         142           40336             0.5     Successful search (ES-wcm)
#      3         146         40335.1             0.5     Successful search (ES-wcm)
#      3         149           40327             0.5     Successful search (ES-wcm)
#      3         150         40325.1             0.5     Successful search (ES-wcm)
#      3         154         40311.7             0.5     Successful search (ES-wcm)
#      3         156         40309.9             0.5     Successful search (ES-wcm)
#      3         158         40302.6             0.5     Successful search (ES-ell)
#      3         162           40290             0.5     Successful search (ES-ell)
#      3         164         40289.8             0.5     Incremental search (ES-ell)
#      3         168         40282.3             0.5     Successful search (ES-ell)
#      3         173         40278.6             0.5     Successful search (ES-ell)
#      3         176         40276.8             0.5     Successful search (ES-ell)
#      3         178         40270.3             0.5     Successful search (ES-ell)
#      3         181         40267.7             0.5     Successful search (ES-ell)
#      3         186         40265.9             0.5     Successful search (ES-ell)
#      3         187         40261.5             0.5     Successful search (ES-ell)
#      3         190           40260             0.5     Successful search (ES-ell)
#      3         193         40258.8             0.5     Successful search (ES-ell)
#      3         196         40258.1             0.5     Successful search (ES-ell)
#      3         201         40257.6             0.5     Successful search (ES-ell)
#      3         202           40257             0.5     Successful search (ES-ell)
#      3         206         40255.9             0.5     Successful search (ES-ell)
#      3         207         40255.8             0.5     Incremental search (ES-ell)
#      3         213         40255.1             0.5     Successful search (ES-ell)
#      3         217         40254.8             0.5     Incremental search (ES-wcm)
#      3         219         40254.6             0.5     Incremental search (ES-ell)
#      3         234         40254.6            0.25         Refine grid             Train
#      4         238         40254.5            0.25     Successful search (ES-ell)
#      4         240         40254.5            0.25     Incremental search (ES-ell)
#      4         247         40254.5            0.25     Incremental search (ES-wcm)
#      4         263         40254.5           0.125         Refine grid             Train
#      5         268         40254.5           0.125     Incremental search (ES-ell)
#      5         285         40254.5          0.0625         Refine grid
#      6         290         40254.4          0.0625     Successful search (ES-wcm)
#      6         298         40254.4          0.0625     Incremental search (ES-wcm)
#      6         301         40254.4          0.0625     Incremental search (ES-ell)
#      6         315         40254.4         0.03125         Refine grid
#      7         317         40254.4         0.03125     Successful search (ES-ell)
#      7         318         40254.4         0.03125     Successful search (ES-ell)
#      7         331         40254.4         0.03125     Incremental search (ES-wcm)
#      7         345         40254.4        0.015625         Refine grid
#      8         349         40254.4        0.015625     Incremental search (ES-wcm)
#      8         367         40254.4       0.0078125         Refine grid
#      9         369         40254.4       0.0078125     Incremental search (ES-ell)
#      9         389         40254.4      0.00390625         Refine grid             Train
#     10         411         40254.2       0.0078125       Successful poll           Train
#     11         416         40254.2       0.0078125     Incremental search (ES-ell)
#     11         433         40254.2      0.00390625         Refine grid             Train
#     12         437         40254.2      0.00390625     Successful search (ES-ell)
#     12         449         40254.2      0.00390625     Incremental search (ES-ell)
#     12         463         40254.2      0.00195312         Refine grid
#     13         486         40254.2     0.000976562         Refine grid             Train
#     14         492         40254.2     0.000976562     Incremental search (ES-ell)
#     14         494         40254.2     0.000976562     Incremental search (ES-ell)
#     14         509         40254.2      0.00195312       Successful poll
#     15         516         40254.2      0.00195312     Incremental search (ES-ell)
#     15         532         40254.2     0.000976562         Refine grid
#     16         538         40254.2     0.000976562     Incremental search (ES-ell)
#     16         555         40254.2     0.000488281         Refine grid             Train
#     17         563         40254.2     0.000488281     Incremental search (ES-ell)
#     17         578         40254.2      0.00012207         Refine grid
#     18         581         40254.2      0.00012207     Incremental search (ES-wcm)
#     18         582         40254.2      0.00012207     Incremental search (ES-ell)
#     18         586         40254.2      0.00012207     Incremental search (ES-wcm)
#     18         601         40254.2     3.05176e-05         Refine grid             Train
#     19         603         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         609         40254.2     3.05176e-05     Incremental search (ES-ell)
#     19         624         40254.2     7.62939e-06         Refine grid             Train
#     20         626         40254.2     7.62939e-06     Incremental search (ES-wcm)
#     20         632         40254.2     7.62939e-06     Incremental search (ES-ell)
#     20         647         40254.2     1.90735e-06         Refine grid             Train
#     21         650         40254.2     1.90735e-06     Incremental search (ES-wcm)
#     21         652         40254.2     1.90735e-06     Incremental search (ES-wcm)
#     21         670         40254.2     4.76837e-07         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 40254.187926958475
#
# Optimization result: [ 0.17534076 27.90160073  1.48279985 73.6659089   0.11028736 79.84883448
#   0.99999999  9.87832327], 40254.187926958475
# 49
# Starting optimization with initial params: [0.1, 35, 1, 40, 0.08, 20, 0.2, -30]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         77304.1               1                                 Uncertainty test
#      0          18           70916               1         Initial mesh            Initial points
#      0          19         65301.5               1       Successful poll           Train
#      1          36         64795.5               1       Successful poll           Train
#      2          38         63952.8               1     Successful search (ES-wcm)
#      2          41         63479.5               1     Successful search (ES-wcm)
#      2          51         63310.3               1     Successful search (ES-wcm)
#      2          52         63047.1               1     Successful search (ES-ell)
#      2          54         62540.1               1     Successful search (ES-ell)
#      2          62         62262.5               1     Successful search (ES-ell)
#      2          63         61997.2               1     Successful search (ES-ell)
#      2          67         61951.2               1     Successful search (ES-ell)
#      2          72         61837.2               1     Successful search (ES-ell)
#      2          80         61833.2               1     Successful search (ES-ell)
#      2          89         61832.7               1     Incremental search (ES-ell)
#      2         100         61832.7             0.5         Refine grid
#      3         101         61809.8             0.5     Successful search (ES-ell)
#      3         103         61797.1             0.5     Successful search (ES-ell)
#      3         108         61775.6             0.5     Successful search (ES-ell)
#      3         113         61775.2             0.5     Successful search (ES-ell)
#      3         115           61772             0.5     Successful search (ES-ell)
#      3         121         61771.5             0.5     Successful search (ES-ell)
#      3         127         61768.3             0.5     Successful search (ES-ell)
#      3         129         61757.3             0.5     Successful search (ES-wcm)
#      3         133         61732.5             0.5     Successful search (ES-wcm)
#      3         140         61720.6             0.5     Successful search (ES-wcm)
#      3         142         61710.2             0.5     Successful search (ES-wcm)
#      3         144         61705.3             0.5     Successful search (ES-wcm)
#      3         150         61702.4             0.5     Successful search (ES-wcm)
#      3         151         61681.4             0.5     Successful search (ES-wcm)
#      3         153           61658             0.5     Successful search (ES-wcm)
#      3         164         61654.3             0.5     Successful search (ES-wcm)
#      3         165         61643.4             0.5     Successful search (ES-wcm)
#      3         174         61634.1             0.5     Successful search (ES-wcm)
#      3         180           61633             0.5     Successful search (ES-wcm)
#      3         184         61632.5             0.5     Successful search (ES-wcm)
#      3         187         61626.7             0.5     Successful search (ES-wcm)
#      3         193         61624.8             0.5     Successful search (ES-wcm)
#      3         199         61622.7             0.5     Successful search (ES-wcm)
#      3         201         61614.4             0.5     Successful search (ES-wcm)
#      3         209         61613.2             0.5     Successful search (ES-wcm)
#      3         211           61609             0.5     Successful search (ES-wcm)
#      3         215         61596.7             0.5     Successful search (ES-wcm)
#      3         218         61593.2             0.5     Successful search (ES-wcm)
#      3         219         61553.8             0.5     Successful search (ES-wcm)
#      3         223         61548.3             0.5     Successful search (ES-wcm)
#      3         226           61523             0.5     Successful search (ES-wcm)
#      3         228         61507.8             0.5     Successful search (ES-wcm)
#      3         234         61503.4             0.5     Successful search (ES-wcm)
#      3         236         61501.8             0.5     Successful search (ES-wcm)
#      3         239         61500.1             0.5     Successful search (ES-wcm)
#      3         241         61497.9             0.5     Successful search (ES-wcm)
#      3         243         61491.7             0.5     Successful search (ES-wcm)
#      3         244         61482.4             0.5     Successful search (ES-wcm)
#      3         250           61481             0.5     Successful search (ES-wcm)
#      3         251         61476.8             0.5     Successful search (ES-wcm)
#      3         254           61475             0.5     Successful search (ES-wcm)
#      3         260         61474.1             0.5     Successful search (ES-wcm)
#      3         265         61472.7             0.5     Successful search (ES-wcm)
#      3         285         61472.7            0.25         Refine grid
#      4         288         61472.4            0.25     Successful search (ES-wcm)
#      4         292         61471.7            0.25     Successful search (ES-wcm)
#      4         313         61471.7           0.125         Refine grid             Train
#      5         333         61471.7          0.0625         Refine grid             Train
#      6         341         61471.6          0.0625     Successful search (ES-wcm)
#      6         362         61471.6         0.03125         Refine grid             Train
#      7         384         61471.6        0.015625         Refine grid             Train
#      8         406         61471.6       0.0078125         Refine grid             Train
#      9         425         61471.6        0.015625       Successful poll           Train
#     10         432         61471.6        0.015625     Successful search (ES-wcm)
#     10         455         61471.6       0.0078125         Refine grid
#     11         477         61471.6      0.00390625         Refine grid             Train
#     12         497         61471.5       0.0078125       Successful poll           Train
#     13         503         61471.5       0.0078125     Successful search (ES-ell)
#     13         527         61471.5      0.00390625         Refine grid             Train
#     14         530         61471.5      0.00390625     Successful search (ES-ell)
#     14         537         61471.5      0.00390625     Successful search (ES-ell)
#     14         539         61471.5      0.00390625     Successful search (ES-wcm)
#     14         540         61471.5      0.00390625     Successful search (ES-wcm)
#     14         550         61471.5      0.00390625     Successful search (ES-wcm)
#     14         553         61471.5      0.00390625     Successful search (ES-ell)
#     14         581         61471.5      0.00195312         Refine grid
#     15         593         61471.4      0.00390625       Successful poll
#     16         599         61471.4      0.00390625     Successful search (ES-ell)
#     16         623         61471.4      0.00195312         Refine grid
#     17         631         61471.4      0.00195312     Incremental search (ES-ell)
#     17         645         61471.4     0.000976562         Refine grid             Train
#     18         647         61471.4     0.000976562     Successful search (ES-wcm)
#     18         650         61471.4     0.000976562     Successful search (ES-wcm)
#     18         653         61471.4     0.000976562     Successful search (ES-wcm)
#     18         656         61471.4     0.000976562     Incremental search (ES-wcm)
#     18         657         61471.4     0.000976562     Successful search (ES-wcm)
#     18         661         61471.4     0.000976562     Successful search (ES-ell)
#     18         663         61471.4     0.000976562     Successful search (ES-ell)
#     18         673         61471.4     0.000976562     Incremental search (ES-ell)
#     18         691         61471.4     0.000488281         Refine grid             Train
#     19         692         61471.4     0.000488281     Successful search (ES-ell)
#     19         694         61471.4     0.000488281     Incremental search (ES-ell)
#     19         695         61471.4     0.000488281     Incremental search (ES-ell)
#     19         698         61471.4     0.000488281     Incremental search (ES-ell)
#     19         705         61471.4     0.000488281     Incremental search (ES-ell)
#     19         721         61471.4     0.000244141         Refine grid             Train
#     20         743         61471.4      0.00012207         Refine grid             Train
#     21         751         61471.4      0.00012207     Incremental search (ES-wcm)
#     21         765         61471.4     6.10352e-05         Refine grid
#     22         773         61471.4     6.10352e-05     Incremental search (ES-wcm)
#     22         787         61471.4     1.52588e-05         Refine grid             Train
#     23         790         61471.4     1.52588e-05     Incremental search (ES-ell)
#     23         809         61471.4      3.8147e-06         Refine grid             Train
#     24         811         61471.4      3.8147e-06     Incremental search (ES-ell)
#     24         813         61471.4      3.8147e-06     Incremental search (ES-ell)
#     24         814         61471.4      3.8147e-06     Incremental search (ES-ell)
#     24         815         61471.4      3.8147e-06     Incremental search (ES-ell)
#     24         817         61471.4      3.8147e-06     Incremental search (ES-ell)
#     24         831         61471.4     9.53674e-07         Refine grid
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 61471.41662371195
#
# Optimization result: [  0.20987932  18.50664201   2.          95.83521218   0.1464438
#   87.00424629   1.         -78.16626189], 61471.41662371195
# Starting optimization with initial params: [0.2, 20, 0.5, 50, 0.06, 30, 0.3, -20]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2           89874               1                                 Uncertainty test
#      0          18           70916               1         Initial mesh            Initial points
#      0          19         65301.5               1       Successful poll           Train
#      1          25         65020.1               1     Successful search (ES-wcm)
#      1          27         64827.4               1     Successful search (ES-wcm)
#      1          29         64687.6               1     Successful search (ES-wcm)
#      1          35         63994.5               1     Successful search (ES-wcm)
#      1          48         63186.2               1       Successful poll
#      2          53         63149.7               1     Successful search (ES-wcm)
#      2          60         63118.6               1     Successful search (ES-wcm)
#      2          61         62777.3               1     Successful search (ES-wcm)
#      2          62         62429.8               1     Successful search (ES-wcm)
#      2          67         62222.5               1     Successful search (ES-wcm)
#      2          70         62213.7               1     Successful search (ES-wcm)
#      2          77         62174.8               1     Successful search (ES-ell)
#      2          80         62078.6               1     Successful search (ES-ell)
#      2          83         62065.2               1     Successful search (ES-ell)
#      2          85         62019.6               1     Successful search (ES-ell)
#      2          87         61839.9               1     Successful search (ES-ell)
#      2          93         61829.4               1     Successful search (ES-ell)
#      2          94           61800               1     Successful search (ES-ell)
#      2         101         61793.5               1     Successful search (ES-wcm)
#      2         103         61772.1               1     Successful search (ES-ell)
#      2         121         61772.1             0.5         Refine grid             Train
#      3         127         61766.1             0.5     Successful search (ES-ell)
#      3         129         61762.1             0.5     Successful search (ES-ell)
#      3         132         61756.5             0.5     Successful search (ES-ell)
#      3         135         61751.7             0.5     Successful search (ES-ell)
#      3         136           61747             0.5     Successful search (ES-ell)
#      3         142         61737.9             0.5     Successful search (ES-ell)
#      3         143         61726.4             0.5     Successful search (ES-ell)
#      3         147         61722.8             0.5     Successful search (ES-ell)
#      3         151         61720.3             0.5     Successful search (ES-ell)
#      3         153         61711.4             0.5     Successful search (ES-ell)
#      3         157           61698             0.5     Successful search (ES-ell)
#      3         161         61693.6             0.5     Successful search (ES-ell)
#      3         167         61683.9             0.5     Successful search (ES-wcm)
#      3         169         61680.6             0.5     Successful search (ES-wcm)
#      3         173         61673.5             0.5     Successful search (ES-wcm)
#      3         175         61650.5             0.5     Successful search (ES-wcm)
#      3         177           61650             0.5     Successful search (ES-wcm)
#      3         178         61645.4             0.5     Successful search (ES-wcm)
#      3         180         61620.1             0.5     Successful search (ES-wcm)
#      3         184         61609.9             0.5     Successful search (ES-wcm)
#      3         189         61609.5             0.5     Successful search (ES-wcm)
#      3         190         61581.7             0.5     Successful search (ES-wcm)
#      3         193         61578.5             0.5     Successful search (ES-wcm)
#      3         197         61575.3             0.5     Successful search (ES-wcm)
#      3         199         61570.6             0.5     Successful search (ES-wcm)
#      3         200         61562.1             0.5     Successful search (ES-wcm)
#      3         204         61555.8             0.5     Successful search (ES-wcm)
#      3         207         61550.2             0.5     Successful search (ES-wcm)
#      3         213         61543.6             0.5     Successful search (ES-wcm)
#      3         220           61540             0.5     Successful search (ES-wcm)
#      3         224         61537.9             0.5     Successful search (ES-wcm)
#      3         225         61536.2             0.5     Successful search (ES-wcm)
#      3         228         61531.7             0.5     Successful search (ES-wcm)
#      3         230         61529.9             0.5     Successful search (ES-wcm)
#      3         231         61523.3             0.5     Successful search (ES-wcm)
#      3         234         61520.1             0.5     Successful search (ES-wcm)
#      3         241         61510.5             0.5     Successful search (ES-ell)
#      3         244         61507.5             0.5     Successful search (ES-ell)
#      3         247         61501.2             0.5     Successful search (ES-ell)
#      3         249         61496.5             0.5     Successful search (ES-ell)
#      3         251         61491.5             0.5     Successful search (ES-ell)
#      3         254         61490.9             0.5     Successful search (ES-ell)
#      3         256         61478.5             0.5     Successful search (ES-ell)
#      3         260         61476.6             0.5     Successful search (ES-ell)
#      3         262         61474.4             0.5     Successful search (ES-wcm)
#      3         267           61474             0.5     Successful search (ES-wcm)
#      3         268         61473.8             0.5     Incremental search (ES-wcm)
#      3         272         61473.6             0.5     Incremental search (ES-wcm)
#      3         276         61473.4             0.5     Incremental search (ES-wcm)
#      3         280         61473.2             0.5     Incremental search (ES-wcm)
#      3         290         61473.2            0.25         Refine grid
#      4         291         61473.1            0.25     Incremental search (ES-wcm)
#      4         296           61473            0.25     Incremental search (ES-wcm)
#      4         298           61473            0.25     Incremental search (ES-wcm)
#      4         310           61473           0.125         Refine grid             Train
#      5         313           61473           0.125     Successful search (ES-wcm)
#      5         315           61473           0.125     Incremental search (ES-wcm)
#      5         319           61473           0.125     Incremental search (ES-wcm)
#      5         325           61473           0.125     Incremental search (ES-wcm)
#      5         338           61473          0.0625         Refine grid
#      6         344           61473          0.0625     Incremental search (ES-wcm)
#      6         347         61472.8           0.125       Successful poll
#      7         353         61472.1           0.125     Successful search (ES-wcm)
#      7         360         61471.9           0.125     Successful search (ES-wcm)
#      7         384         61471.9          0.0625         Refine grid             Train
#      8         392         61471.7          0.0625     Successful search (ES-ell)
#      8         413         61471.7         0.03125         Refine grid
#      9         421         61471.6         0.03125     Successful search (ES-ell)
#      9         443         61471.6        0.015625         Refine grid
# ...
#     25         815         52852.3      0.00195312     Successful search (ES-wcm)
#     25         816         52852.1      0.00195312     Successful search (ES-wcm)
#     25         824         52852.1      0.00195312     Successful search (ES-wcm)
#     25         847           52852      0.00390625       Successful poll           Train
#     26         868           52852       0.0078125       Successful poll           Train
#     27         875           52852       0.0078125     Successful search (ES-ell)
#     27         899           52852      0.00390625         Refine grid
#     28         905           52852      0.00390625     Successful search (ES-ell)
#     28         930           52852      0.00195312         Refine grid             Train
#     29         953           52852     0.000976562         Refine grid             Train
#     30         976           52852     0.000488281         Refine grid             Train
#     31         999           52852     0.000976562       Successful poll           Train
#     32        1022           52852     0.000488281         Refine grid             Train
#     33        1030           52852     0.000488281     Incremental search (ES-ell)
#     33        1045           52852     0.000244141         Refine grid
#     34        1068           52852      0.00012207         Refine grid             Train
#     35        1069           52852      0.00012207     Successful search (ES-ell)
#     35        1070           52852      0.00012207     Successful search (ES-ell)
#     35        1073           52852      0.00012207     Incremental search (ES-ell)
#     35        1076           52852      0.00012207     Incremental search (ES-ell)
#     35        1099           52852     6.10352e-05         Refine grid             Train
#     36        1122           52852     3.05176e-05         Refine grid             Train
#     37        1146           52852     1.52588e-05         Refine grid             Train
#     38        1147           52852     1.52588e-05     Incremental search (ES-ell)
#     38        1148           52852     1.52588e-05     Incremental search (ES-ell)
#     38        1149           52852     1.52588e-05     Incremental search (ES-ell)
#     38        1150           52852     1.52588e-05     Incremental search (ES-ell)
#     38        1152           52852     1.52588e-05     Incremental search (ES-ell)
#     38        1169           52852     7.62939e-06         Refine grid
#     39        1170           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1171           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1172           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1174           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1175           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1176           52852     7.62939e-06     Incremental search (ES-ell)
#     39        1193           52852      3.8147e-06         Refine grid
#     40        1195           52852      3.8147e-06     Incremental search (ES-ell)
#     40        1197           52852      3.8147e-06     Incremental search (ES-wcm)
#     40        1199           52852      3.8147e-06     Incremental search (ES-ell)
#     40        1200           52852      3.8147e-06     Incremental search (ES-ell)
#     40        1216           52852     1.90735e-06         Refine grid             Train
#     41        1219           52852     1.90735e-06     Incremental search (ES-ell)
#     41        1220           52852     1.90735e-06     Incremental search (ES-ell)
#     41        1239           52852     9.53674e-07         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 52851.99352780671
#
# Optimization result: [ 1.31400996e-01  3.37972385e+01  7.60292156e-01  9.10650272e+01
#   4.78055524e-02  5.63171131e+01  9.99999847e-01 -7.91397136e+01], 52851.99352780671
# Starting optimization with initial params: [0.25, 30, 0.75, 60, 0.1, 50, 0.1, -10]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         73583.6               1                                 Uncertainty test
#      0          18           61355               1         Initial mesh            Initial points
#      0          19         54992.5               1       Successful poll           Train
#      1          20         54352.9               1     Successful search (ES-wcm)
#      1          23         54285.4               1     Successful search (ES-wcm)
#      1          31         53617.1               1     Successful search (ES-wcm)
#      1          33         53591.2               1     Successful search (ES-wcm)
#      1          40         53424.9               1     Successful search (ES-wcm)
#      1          49         53415.6               1     Successful search (ES-wcm)
#      1          59         53336.8               1     Successful search (ES-wcm)
#      1          63         53243.6               1     Successful search (ES-wcm)
#      1          65           52965               1     Successful search (ES-wcm)
#      1          75         52957.3               1     Successful search (ES-wcm)
#      1          78         52955.4               1     Successful search (ES-ell)
#      1          88         52921.7               1     Successful search (ES-wcm)
#      1          96         52917.5               1     Successful search (ES-wcm)
#      1         105           52913               1     Successful search (ES-wcm)
#      1         107         52904.4               1     Successful search (ES-ell)
#      1         111         52901.7               1     Successful search (ES-ell)
#      1         112         52895.6               1     Successful search (ES-ell)
#      1         118         52894.5               1     Successful search (ES-ell)
#      1         127         52893.3               1     Successful search (ES-ell)
#      1         136         52891.5               1     Successful search (ES-ell)
#      1         159         52891.5             0.5         Refine grid             Train
#      2         161         52884.6             0.5     Successful search (ES-ell)
#      2         164         52880.5             0.5     Successful search (ES-ell)
#      2         166         52879.6             0.5     Successful search (ES-ell)
#      2         168         52879.1             0.5     Successful search (ES-ell)
#      2         171         52877.7             0.5     Successful search (ES-ell)
#      2         173         52874.3             0.5     Successful search (ES-wcm)
#      2         180         52863.9             0.5     Successful search (ES-wcm)
#      2         186         52860.3             0.5     Successful search (ES-wcm)
#      2         191         52859.1             0.5     Successful search (ES-wcm)
#      2         195           52856             0.5     Successful search (ES-wcm)
#      2         205         52855.9             0.5     Incremental search (ES-wcm)
#      2         207         52855.5             0.5     Successful search (ES-wcm)
#      2         210         52855.2             0.5     Incremental search (ES-wcm)
#      2         227         52855.2            0.25         Refine grid             Train
#      3         230         52852.9            0.25     Successful search (ES-wcm)
#      3         242         52852.9            0.25     Incremental search (ES-wcm)
#      3         256         52852.9           0.125         Refine grid
#      4         264         52852.7           0.125     Successful search (ES-wcm)
#      4         285         52852.7          0.0625         Refine grid
#      5         307         52852.7         0.03125         Refine grid             Train
#      6         329         52852.7        0.015625         Refine grid             Train
#      7         352         52852.7      0.00390625         Refine grid             Train
#      8         360         52852.7      0.00390625     Successful search (ES-ell)
#      8         383         52852.6       0.0078125       Successful poll
#      9         396         52852.6        0.015625       Successful poll
#     10         404         52852.6        0.015625     Successful search (ES-wcm)
#     10         427         52852.6       0.0078125         Refine grid             Train
#     11         432         52852.6       0.0078125     Incremental search (ES-wcm)
#     11         439         52852.4        0.015625       Successful poll
#     12         462         52852.4       0.0078125         Refine grid             Train
#     13         481         52852.4        0.015625       Successful poll           Train
#     14         504         52852.4       0.0078125         Refine grid             Train
#     15         527         52852.4      0.00390625         Refine grid             Train
#     16         535         52852.4      0.00390625     Successful search (ES-wcm)
#     16         539         52852.4      0.00390625     Successful search (ES-wcm)
#     16         565         52852.4       0.0078125       Successful poll
#     17         588         52852.4      0.00390625         Refine grid             Train
#     18         611         52852.4      0.00195312         Refine grid             Train
#     19         614         52852.4      0.00195312     Successful search (ES-wcm)
#     19         622         52852.4      0.00195312     Incremental search (ES-wcm)
#     19         641         52852.2      0.00390625       Successful poll
#     20         664         52852.2      0.00195312         Refine grid             Train
#     21         686         52852.2      0.00390625       Successful poll           Train
#     22         709         52852.2      0.00195312         Refine grid             Train
#     23         731         52852.2      0.00390625       Successful poll           Train
#     24         754         52852.2      0.00195312         Refine grid             Train
#     25         777         52852.2     0.000976562         Refine grid             Train
#     26         778         52852.2     0.000976562     Successful search (ES-wcm)
#     26         789         52852.2     0.000976562     Successful search (ES-wcm)
#     26         801         52852.2     0.000976562     Incremental search (ES-wcm)
#     26         814         52852.1      0.00195312       Successful poll           Train
#     27         837         52852.1      0.00390625       Successful poll           Train
#     28         844         52852.1      0.00390625     Incremental search (ES-ell)
#     28         860         52852.1      0.00195312         Refine grid             Train
#     29         865         52852.1      0.00195312     Successful search (ES-ell)
#     29         868         52852.1      0.00195312     Successful search (ES-wcm)
#     29         873         52852.1      0.00195312     Successful search (ES-wcm)
#     29         876         52852.1      0.00195312     Successful search (ES-wcm)
#     29         883         52852.1      0.00195312     Successful search (ES-wcm)
#     29         906         52852.1      0.00390625       Successful poll           Train
#     30         909         52852.1      0.00390625     Successful search (ES-wcm)
#     30         914         52852.1      0.00390625     Successful search (ES-wcm)
#     30         918         52852.1      0.00390625     Successful search (ES-wcm)
#     30         922         52852.1      0.00390625     Successful search (ES-wcm)
#     30         945         52852.1      0.00195312         Refine grid             Train
#     31         953         52852.1      0.00195312     Incremental search (ES-ell)
#     31         968         52852.1     0.000976562         Refine grid             Train
#     32         970         52852.1     0.000976562     Successful search (ES-ell)
#     32         972         52852.1     0.000976562     Successful search (ES-ell)
#     32         974         52852.1     0.000976562     Successful search (ES-ell)
#     32         977         52852.1     0.000976562     Successful search (ES-ell)
#     32         978         52852.1     0.000976562     Successful search (ES-ell)
#     32         981         52852.1     0.000976562     Successful search (ES-ell)
#     32         992         52852.1     0.000976562     Incremental search (ES-ell)
#     32        1005         52852.1      0.00195312       Successful poll
#     33        1010         52852.1      0.00195312     Incremental search (ES-wcm)
#     33        1011         52851.9      0.00195312     Successful search (ES-ell)
#     33        1036         52851.9     0.000976562         Refine grid
#     34        1044         52851.9     0.000976562     Incremental search (ES-ell)
#     34        1059         52851.9     0.000488281         Refine grid             Train
#     35        1063         52851.9     0.000488281     Successful search (ES-ell)
#     35        1090         52851.9     0.000244141         Refine grid             Train
#     36        1091         52851.9     0.000244141     Incremental search (ES-ell)
#     36        1113         52851.9     0.000488281       Successful poll           Train
#     37        1136         52851.9     0.000244141         Refine grid             Train
#     38        1159         52851.9      0.00012207         Refine grid             Train
#     39        1160         52851.9      0.00012207     Incremental search (ES-wcm)
#     39        1164         52851.9      0.00012207     Incremental search (ES-wcm)
#     39        1182         52851.9     6.10352e-05         Refine grid
#     40        1183         52851.9     6.10352e-05     Incremental search (ES-ell)
#     40        1205         52851.9     3.05176e-05         Refine grid             Train
#     41        1208         52851.9     3.05176e-05     Incremental search (ES-ell)
#     41        1228         52851.9     1.52588e-05         Refine grid
#     42        1234         52851.9     1.52588e-05     Incremental search (ES-ell)
#     42        1251         52851.9      3.8147e-06         Refine grid             Train
#     43        1253         52851.9      3.8147e-06     Incremental search (ES-wcm)
#     43        1256         52851.9      3.8147e-06     Incremental search (ES-wcm)
#     43        1257         52851.9      3.8147e-06     Incremental search (ES-wcm)
#     43        1258         52851.9      3.8147e-06     Incremental search (ES-wcm)
#     43        1274         52851.9     9.53674e-07         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 52851.85946698425
#
# Optimization result: [ 1.30220759e-01  3.41637542e+01  7.40228141e-01  9.10212701e+01
#   4.79318898e-02  5.63631627e+01  1.00000000e+00 -7.91396924e+01], 52851.85946698425

# %%
np.exp(10.3)
# Out:
# 29732.618852891435

# %%
results_df.to_csv('tied_pa_accu_fit_delta_612.csv', index=False)

# %%
def total_log_likelihood(data, params):
    rt_vect=np.array(data['RT_ms'])
    abl_vect=np.array(data['ABL'])
    ild_vect=np.array(data['|ILD|'])
    fix_vect=np.array(data['intended_fix_ms'])
    out_vect=np.array(data['success'])
    model = model_tach_shift(RT=rt_vect,ABL=abl_vect,ILD=ild_vect,t_fix=fix_vect, out=out_vect)
    params1 = list(params) + [10]
    model.set_params(params1)
    logL = model.log_likelihood()
    return np.sum(logL)
def objective_function(params, data):
    """ 
    Compute the negative log-likelihood for the DDM parameters.
    
    :param params: array of model parameters [v, a, x1, x2, x3, x4]
    :param data: DataFrame with the experimental data
    :return: Negative log-likelihood

    """ # Assuming x includes 4 parameters
    x=params
    # Calculate the total log likelihood using the defined function
    total_likelihood = total_log_likelihood(data, x)
    # BADS minimizes the function, so return negative log likelihood
    return -total_likelihood
#creat a suitable function for bads

def objective_fun_forbads(params):
    data= df_animal
    return objective_function(params, data)

# x = [compressive_power, a_tied, T0, ndt, v, a, w_tse, Delta]
initial_param_sets = [
    [0.1, 35, 1, 40,0.08,20,0.2],
    [0.2, 20, 0.5, 50,0.06,30,0.3],
    [0.25, 30, 0.75,60, 0.1, 50,0.1]
] 
lower_bounds = [0.03, 10, 0.05, 0,0 ,10, 0]  # Hard lower bounds
upper_bounds = [0.5, 80, 3, 100, 1, 100, 1]  # Hard upper bounds
plausible_lb = [0.04, 15, 0.1,10, 0.02,15, 0.01]  # Plausible lower bounds
plausible_ub = [0.4, 60, 2.5, 80, 0.8, 80, 0.9]  # Plausible upper bounds

# Run optimization for each animal
all_results = []
animal_value= df['animal'].unique()
for idx, animal in enumerate(animal_value):
    print(animal)
    best_result = None
    df_animal = df[(df['animal'] == animal)&(df['max_samplingTime']==6)]
    row_count = len(df_animal)
    for i, initial_params in enumerate(initial_param_sets):
        print(f"Starting optimization with initial params: {initial_params}")
        bads = BADS(objective_fun_forbads, initial_params, lower_bounds, upper_bounds, plausible_lb, plausible_ub)
        optimize_result = bads.optimize()
        result_details = {
            'animal': animal,
            'initial_params': str(initial_params),
            'optimized_params': str(optimize_result.x),
            'result_fun': optimize_result.fval,
            'row_count': row_count,
            'is_best': 0  # Default to 0, will update later if it's the best
        }
        print(f"Optimization result: {optimize_result.x}, {optimize_result.fval}")
        all_results.append(result_details)

        # Update the best result if it's the first run or better than the previous best
        if best_result is None or optimize_result.fval < best_result.fval:
            best_result = optimize_result
            best_params = initial_params

    # Update the best result indicator for the best optimization run
    for result in all_results:
        if result['animal'] == animal and result['initial_params'] == str(best_params):
            result['is_best'] = 1

# Convert all_results to a DataFrame
results_df = pd.DataFrame(all_results)
results_df.to_csv('tied_pa_accu_fit_delta10_new.csv', index=False)
# Out:
# 48
# Starting optimization with initial params: [0.1, 35, 1, 40, 0.08, 20, 0.2]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2           50340               1                                 Uncertainty test
#      0          10         41315.1               1         Initial mesh            Initial points
#      0          19         41140.1               1       Successful poll           Train
#      1          25           41077               1     Successful search (ES-ell)
#      1          33         41069.5               1     Successful search (ES-ell)
#      1          38         41068.5               1     Successful search (ES-ell)
#      1          45         40979.1               1     Successful search (ES-ell)
#      1          52         40838.1               1     Successful search (ES-ell)
#      1          53         40750.2               1     Successful search (ES-ell)
#      1          57         40585.4               1     Successful search (ES-ell)
#      1          65         40552.7               1     Successful search (ES-ell)
#      1          68         40500.1               1     Successful search (ES-wcm)
#      1          75         40449.8               1     Successful search (ES-wcm)
#      1          79         40446.8               1     Successful search (ES-ell)
#      1          82         40426.1               1     Successful search (ES-wcm)
#      1          85         40366.6               1     Successful search (ES-wcm)
#      1          89         40362.2               1     Successful search (ES-wcm)
#      1          94           40340               1     Successful search (ES-wcm)
#      1         103         40324.4               1     Successful search (ES-wcm)
#      1         108         40310.3               1     Successful search (ES-wcm)
#      1         109         40285.5               1     Successful search (ES-ell)
#      1         115         40285.4               1     Incremental search (ES-ell)
#      1         124         40285.4             0.5         Refine grid
#      2         127         40279.4             0.5     Successful search (ES-ell)
#      2         129         40277.4             0.5     Successful search (ES-ell)
#      2         131         40276.7             0.5     Successful search (ES-ell)
#      2         136           40260             0.5     Successful search (ES-ell)
#      2         145           40259             0.5     Successful search (ES-ell)
#      2         147           40258             0.5     Successful search (ES-ell)
#      2         150         40257.4             0.5     Successful search (ES-ell)
#      2         151         40256.6             0.5     Successful search (ES-ell)
#      2         156           40255             0.5     Successful search (ES-ell)
#      2         159         40254.7             0.5     Incremental search (ES-ell)
#      2         162         40254.7             0.5     Incremental search (ES-ell)
#      2         177         40254.7            0.25         Refine grid             Train
#      3         179         40254.4            0.25     Successful search (ES-ell)
#      3         183         40254.4            0.25     Incremental search (ES-wcm)
#      3         188         40254.4            0.25     Incremental search (ES-wcm)
#      3         204         40254.4           0.125         Refine grid             Train
#      4         208         40254.4           0.125     Incremental search (ES-ell)
#      4         211         40254.4           0.125     Incremental search (ES-wcm)
#      4         224         40254.4          0.0625         Refine grid
#      5         244         40254.4         0.03125         Refine grid
#      6         264         40254.4        0.015625         Refine grid             Train
#      7         269         40254.4        0.015625     Successful search (ES-ell)
#      7         291         40254.4       0.0078125         Refine grid
#      8         298         40254.4       0.0078125     Successful search (ES-wcm)
#      8         299         40254.4       0.0078125     Successful search (ES-ell)
#      8         301         40254.4       0.0078125     Incremental search (ES-wcm)
#      8         304         40254.4       0.0078125     Incremental search (ES-wcm)
#      8         306         40254.4       0.0078125     Incremental search (ES-ell)
#      8         308         40254.4       0.0078125     Incremental search (ES-wcm)
#      8         325         40254.4      0.00390625         Refine grid
#      9         327         40254.4      0.00390625     Incremental search (ES-ell)
#      9         330         40254.4      0.00390625     Incremental search (ES-ell)
#      9         345         40254.4      0.00195312         Refine grid             Train
#     10         365         40254.4     0.000976562         Refine grid             Train
#     11         367         40254.4     0.000976562     Incremental search (ES-ell)
#     11         385         40254.4     0.000244141         Refine grid             Train
#     12         389         40254.4     0.000244141     Incremental search (ES-ell)
#     12         405         40254.4     6.10352e-05         Refine grid             Train
#     13         406         40254.4     6.10352e-05     Incremental search (ES-wcm)
#     13         411         40254.4     6.10352e-05     Incremental search (ES-ell)
#     13         425         40254.4     1.52588e-05         Refine grid             Train
#     14         427         40254.4     1.52588e-05     Incremental search (ES-wcm)
#     14         429         40254.4     1.52588e-05     Incremental search (ES-wcm)
#     14         431         40254.4     1.52588e-05     Incremental search (ES-ell)
#     14         445         40254.4      3.8147e-06         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 40254.35568659615
#
# Optimization result: [ 0.17532193 27.88137358  1.48309482 73.71471454  0.11023671 79.82867183
#   1.        ], 40254.35568659615
# Starting optimization with initial params: [0.2, 20, 0.5, 50, 0.06, 30, 0.3]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2           66383               1                                 Uncertainty test
#      0          10         41315.1               1         Initial mesh            Initial points
#      0          19         41140.1               1       Successful poll           Train
#      1          36         41140.1             0.5         Refine grid             Train
#      2          39         40950.4             0.5     Successful search (ES-wcm)
#      2          42         40727.8             0.5     Successful search (ES-wcm)
#      2          47         40691.3             0.5     Successful search (ES-wcm)
#      2          49         40595.2             0.5     Successful search (ES-wcm)
#      2          53         40557.5             0.5     Successful search (ES-wcm)
#      2          56         40516.9             0.5     Successful search (ES-wcm)
#      2          60         40436.5             0.5     Successful search (ES-ell)
#      2          61         40432.4             0.5     Successful search (ES-ell)
#      2          67         40427.3             0.5     Successful search (ES-ell)
#      2          75         40417.8             0.5     Successful search (ES-ell)
#      2          78           40370             0.5     Successful search (ES-ell)
#      2          82           40362             0.5     Successful search (ES-ell)
#      2          85         40353.2             0.5     Successful search (ES-ell)
#      2          90           40352             0.5     Successful search (ES-ell)
#      2          95         40339.4             0.5     Successful search (ES-wcm)
#      2         105         40335.3             0.5     Successful search (ES-wcm)
#      2         108         40332.1             0.5     Successful search (ES-wcm)
#      2         117         40311.6             0.5     Successful search (ES-wcm)
#      2         119         40302.8             0.5     Successful search (ES-wcm)
#      2         123         40294.3             0.5     Successful search (ES-wcm)
#      2         125         40290.6             0.5     Successful search (ES-wcm)
#      2         128         40282.4             0.5     Successful search (ES-wcm)
#      2         132         40271.6             0.5     Successful search (ES-wcm)
#      2         135         40268.4             0.5     Successful search (ES-wcm)
#      2         141         40264.8             0.5     Successful search (ES-wcm)
#      2         144         40263.5             0.5     Successful search (ES-wcm)
#      2         146         40263.1             0.5     Successful search (ES-wcm)
#      2         151         40262.5             0.5     Successful search (ES-wcm)
#      2         154         40261.3             0.5     Successful search (ES-wcm)
#      2         157         40260.1             0.5     Successful search (ES-wcm)
#      2         161         40258.8             0.5     Successful search (ES-wcm)
#      2         166         40258.4             0.5     Incremental search (ES-wcm)
#      2         181         40258.4            0.25         Refine grid             Train
#      3         183         40255.7            0.25     Successful search (ES-wcm)
#      3         188         40255.3            0.25     Successful search (ES-wcm)
#      3         193         40254.8            0.25     Successful search (ES-wcm)
#      3         194         40254.6            0.25     Successful search (ES-wcm)
#      3         202         40254.5            0.25     Incremental search (ES-wcm)
#      3         215         40254.5           0.125         Refine grid
#      4         218         40254.4           0.125     Successful search (ES-wcm)
#      4         219         40254.4           0.125     Successful search (ES-wcm)
#      4         222         40254.4           0.125     Incremental search (ES-wcm)
#      4         242         40254.4          0.0625         Refine grid
#      5         262         40254.4         0.03125         Refine grid
#      6         265         40254.4         0.03125     Incremental search (ES-wcm)
#      6         282         40254.4        0.015625         Refine grid
#      7         302         40254.4       0.0078125         Refine grid             Train
#      8         309         40254.4       0.0078125     Incremental search (ES-ell)
#      8         322         40254.4      0.00390625         Refine grid             Train
#      9         328         40254.4      0.00390625     Successful search (ES-wcm)
#      9         349         40254.4      0.00195312         Refine grid             Train
#     10         369         40254.4     0.000976562         Refine grid             Train
#     11         379         40254.4      0.00195312       Successful poll           Train
#     12         383         40254.4      0.00195312     Incremental search (ES-ell)
#     12         386         40254.4      0.00195312     Incremental search (ES-wcm)
#     12         399         40254.4     0.000976562         Refine grid             Train
#     13         400         40254.4     0.000976562     Incremental search (ES-ell)
#     13         405         40254.4     0.000976562     Incremental search (ES-wcm)
#     13         419         40254.4     0.000488281         Refine grid             Train
#     14         439         40254.4      0.00012207         Refine grid             Train
#     15         442         40254.4      0.00012207     Incremental search (ES-wcm)
#     15         443         40254.4      0.00012207     Incremental search (ES-wcm)
#     15         459         40254.4     3.05176e-05         Refine grid             Train
#     16         460         40254.4     3.05176e-05     Incremental search (ES-wcm)
#     16         465         40254.4     3.05176e-05     Incremental search (ES-wcm)
#     16         466         40254.4     3.05176e-05     Incremental search (ES-wcm)
#     16         479         40254.4     7.62939e-06         Refine grid             Train
#     17         485         40254.4     7.62939e-06     Incremental search (ES-wcm)
#     17         499         40254.4     1.90735e-06         Refine grid
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 40254.356642459665
#
# Optimization result: [ 0.17565008 27.82056624  1.4919715  73.71965828  0.11025876 79.83696138
#   1.        ], 40254.356642459665
# Starting optimization with initial params: [0.25, 30, 0.75, 60, 0.1, 50, 0.1]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         52251.5               1                                 Uncertainty test
#      0          10         41315.1               1         Initial mesh            Initial points
#      0          19         41140.1               1       Successful poll           Train
#      1          23         40867.9               1     Successful search (ES-wcm)
#      1          30         40837.5               1     Successful search (ES-wcm)
#      1          38         40720.5               1     Successful search (ES-wcm)
#      1          39         40472.8               1     Successful search (ES-wcm)
#      1          47         40470.1               1     Successful search (ES-wcm)
#      1          53         40387.9               1     Successful search (ES-wcm)
#      1          58         40369.8               1     Successful search (ES-ell)
#      1          78         40369.8             0.5         Refine grid             Train
#      2          83         40369.7             0.5     Incremental search (ES-ell)
#      2          84         40351.5             0.5     Successful search (ES-ell)
#      2          91           40343             0.5     Successful search (ES-ell)
#      2          95         40323.7             0.5     Successful search (ES-ell)
#      2         102         40320.9             0.5     Successful search (ES-ell)
#      2         104         40319.2             0.5     Successful search (ES-wcm)
#      2         112         40308.3             0.5     Successful search (ES-wcm)
#      2         115         40308.2             0.5     Incremental search (ES-wcm)
#      2         131         40308.2            0.25         Refine grid             Train
#      3         134         40289.7            0.25     Successful search (ES-ell)
#      3         136         40275.7            0.25     Successful search (ES-ell)
#      3         143         40273.9            0.25     Successful search (ES-ell)
#      3         145         40272.3            0.25     Successful search (ES-ell)
#      3         148           40270            0.25     Successful search (ES-ell)
#      3         152         40269.7            0.25     Successful search (ES-ell)
#      3         154         40267.9            0.25     Successful search (ES-ell)
#      3         156           40267            0.25     Successful search (ES-ell)
#      3         158         40262.9            0.25     Successful search (ES-ell)
#      3         164         40261.2            0.25     Successful search (ES-ell)
#      3         165         40259.9            0.25     Successful search (ES-ell)
#      3         171         40259.3            0.25     Successful search (ES-ell)
#      3         173         40258.6            0.25     Successful search (ES-ell)
#      3         177           40258            0.25     Successful search (ES-ell)
#      3         180         40256.7            0.25     Successful search (ES-wcm)
#      3         184         40255.8            0.25     Successful search (ES-wcm)
#      3         187           40255            0.25     Successful search (ES-wcm)
#      3         192         40254.8            0.25     Successful search (ES-wcm)
#      3         198         40254.6            0.25     Successful search (ES-wcm)
#      3         200         40254.5            0.25     Incremental search (ES-wcm)
#      3         207         40254.4            0.25     Incremental search (ES-ell)
#      3         221         40254.4           0.125         Refine grid
#      4         227         40254.4           0.125     Successful search (ES-wcm)
#      4         228         40254.4           0.125     Incremental search (ES-wcm)
#      4         233         40254.4           0.125     Incremental search (ES-wcm)
#      4         248         40254.4          0.0625         Refine grid
#      5         268         40254.4         0.03125         Refine grid             Train
#      6         270         40254.4         0.03125     Incremental search (ES-wcm)
#      6         272         40254.4         0.03125     Incremental search (ES-wcm)
#      6         275         40254.4         0.03125     Incremental search (ES-wcm)
#      6         288         40254.4        0.015625         Refine grid
#      7         289         40254.4        0.015625     Incremental search (ES-wcm)
#      7         293         40254.4        0.015625     Incremental search (ES-wcm)
#      7         308         40254.4       0.0078125         Refine grid             Train
#      8         328         40254.4      0.00390625         Refine grid             Train
#      9         334         40254.4      0.00390625     Incremental search (ES-wcm)
#      9         348         40254.4     0.000976562         Refine grid             Train
#     10         349         40254.4     0.000976562     Incremental search (ES-ell)
#     10         350         40254.4     0.000976562     Incremental search (ES-wcm)
#     10         368         40254.4     0.000488281         Refine grid             Train
#     11         388         40254.4     0.000244141         Refine grid             Train
#     12         390         40254.4     0.000244141     Incremental search (ES-wcm)
#     12         394         40254.4     0.000244141     Incremental search (ES-ell)
#     12         408         40254.4      0.00012207         Refine grid             Train
#     13         411         40254.4      0.00012207     Incremental search (ES-wcm)
#     13         413         40254.4      0.00012207     Incremental search (ES-ell)
#     13         414         40254.4      0.00012207     Incremental search (ES-wcm)
#     13         428         40254.4     3.05176e-05         Refine grid
#     14         448         40254.4     7.62939e-06         Refine grid             Train
#     15         449         40254.4     7.62939e-06     Incremental search (ES-wcm)
#     15         450         40254.4     7.62939e-06     Incremental search (ES-wcm)
#     15         455         40254.4     7.62939e-06     Incremental search (ES-wcm)
#     15         468         40254.4     1.90735e-06         Refine grid
#     16         472         40254.4     1.90735e-06     Incremental search (ES-wcm)
#     16         473         40254.4     1.90735e-06     Incremental search (ES-ell)
#     16         488         40254.4     4.76837e-07         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_mesh']
# Function value at minimum: 40254.35575626907
#
# Optimization result: [ 0.17524487 27.90078433  1.4807062  73.70855052  0.11025537 79.83782662
#   1.        ], 40254.35575626907
# 49
# Starting optimization with initial params: [0.1, 35, 1, 40, 0.08, 20, 0.2]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         77661.6               1                                 Uncertainty test
#      0          10         64771.5               1         Initial mesh            Initial points
#      0          20         64771.5             0.5         Refine grid             Train
#      1          24         64562.5             0.5     Successful search (ES-wcm)
#      1          26         64074.7             0.5     Successful search (ES-ell)
#      1          27         63875.5             0.5     Successful search (ES-ell)
#      1          29         63339.3             0.5     Successful search (ES-ell)
#      1          32         62930.2             0.5     Successful search (ES-ell)
#      1          53         62930.2            0.25         Refine grid             Train
#      2          56         62816.8            0.25     Successful search (ES-ell)
#      2          57         62699.8            0.25     Successful search (ES-ell)
#      2          58         62576.9            0.25     Successful search (ES-ell)
#      2          61         62532.8            0.25     Successful search (ES-ell)
#      2          64         62466.9            0.25     Successful search (ES-ell)
#      2          70         62427.8            0.25     Successful search (ES-ell)
#      2          72         62423.5            0.25     Successful search (ES-ell)
#      2          80         62415.4            0.25     Successful search (ES-ell)
#      2          81         62414.4            0.25     Successful search (ES-ell)
#      2          83         62409.7            0.25     Successful search (ES-wcm)
#      2          87         62408.3            0.25     Successful search (ES-wcm)
#      2          88         62392.4            0.25     Successful search (ES-wcm)
#      2          92         62388.2            0.25     Successful search (ES-wcm)
#      2          94         62376.9            0.25     Successful search (ES-wcm)
#      2          95         62372.3            0.25     Successful search (ES-wcm)
#      2         100         62366.5            0.25     Successful search (ES-wcm)
#      2         101         62359.5            0.25     Successful search (ES-ell)
#      2         103         62350.5            0.25     Successful search (ES-ell)
#      2         107           62346            0.25     Successful search (ES-ell)
#      2         109         62331.4            0.25     Successful search (ES-ell)
#      2         112         62313.8            0.25     Successful search (ES-ell)
#      2         114         62313.7            0.25     Incremental search (ES-ell)
#      2         119         62306.5            0.25     Successful search (ES-ell)
#      2         120         62304.9            0.25     Successful search (ES-ell)
#      2         123         62295.1            0.25     Successful search (ES-ell)
#      2         127         62282.8            0.25     Successful search (ES-ell)
#      2         134         62281.8            0.25     Successful search (ES-ell)
#      2         137         62281.6            0.25     Successful search (ES-ell)
#      2         138         62281.5            0.25     Incremental search (ES-ell)
#      2         142         62276.1            0.25     Successful search (ES-ell)
#      2         146         62269.5            0.25     Successful search (ES-ell)
#      2         151         62267.7            0.25     Successful search (ES-ell)
#      2         155         62267.6            0.25     Successful search (ES-ell)
#      2         157         62267.1            0.25     Successful search (ES-ell)
#      2         158         62266.4            0.25     Successful search (ES-ell)
#      2         161         62266.1            0.25     Successful search (ES-ell)
#      2         164         62266.1            0.25     Incremental search (ES-ell)
#      2         167           62266            0.25     Incremental search (ES-ell)
#      2         172           62266            0.25     Incremental search (ES-ell)
#      2         183           62266           0.125         Refine grid             Train
#      3         184         62265.9           0.125     Successful search (ES-ell)
#      3         188         62265.9           0.125     Incremental search (ES-ell)
#      3         193         62265.9           0.125     Incremental search (ES-ell)
#      3         210         62265.9          0.0625         Refine grid
#      4         214         62265.9          0.0625     Incremental search (ES-wcm)
#      4         230         62265.9         0.03125         Refine grid             Train
#      5         231         62265.9         0.03125     Successful search (ES-ell)
#      5         233         62265.9         0.03125     Successful search (ES-wcm)
#      5         236         62265.9         0.03125     Incremental search (ES-wcm)
#      5         240         62265.9         0.03125     Incremental search (ES-wcm)
#      5         257         62265.9        0.015625         Refine grid             Train
#      6         260         62265.9        0.015625     Incremental search (ES-wcm)
#      6         262         62265.9        0.015625     Incremental search (ES-wcm)
#      6         277         62265.9       0.0078125         Refine grid
#      7         281         62265.9       0.0078125     Incremental search (ES-wcm)
#      7         283         62265.9       0.0078125     Incremental search (ES-wcm)
#      7         297         62265.9      0.00390625         Refine grid             Train
#      8         317         62265.9      0.00195312         Refine grid             Train
#      9         321         62265.9      0.00195312     Incremental search (ES-ell)
#      9         337         62265.9     0.000488281         Refine grid
#     10         357         62265.9      0.00012207         Refine grid             Train
#     11         377         62265.9     3.05176e-05         Refine grid             Train
#     12         397         62265.9     7.62939e-06         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 62265.86210040202
#
# Optimization result: [ 0.22897799 19.67763992  2.08961836 95.68427816  0.14739094 87.19274719
#   1.        ], 62265.86210040202
# Starting optimization with initial params: [0.2, 20, 0.5, 50, 0.06, 30, 0.3]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         90059.1               1                                 Uncertainty test
#      0          10         64771.5               1         Initial mesh            Initial points
#      0          20         64771.5             0.5         Refine grid             Train
#      1          24         64027.7             0.5     Successful search (ES-ell)
#      1          25         63649.5             0.5     Successful search (ES-ell)
#      1          28           63124             0.5     Successful search (ES-ell)
#      1          31         62704.3             0.5     Successful search (ES-ell)
#      1          37         62605.8             0.5     Successful search (ES-ell)
#      1          46         62604.4             0.5     Successful search (ES-ell)
#      1          52         62585.7             0.5     Successful search (ES-ell)
#      1          54         62573.6             0.5     Successful search (ES-ell)
#      1          74         62573.6            0.25         Refine grid             Train
#      2          78         62563.1            0.25     Successful search (ES-ell)
#      2          80         62558.5            0.25     Successful search (ES-ell)
#      2          86         62530.6            0.25     Successful search (ES-wcm)
#      2          88         62520.8            0.25     Successful search (ES-wcm)
#      2          92         62514.6            0.25     Successful search (ES-wcm)
#      2          94         62503.4            0.25     Successful search (ES-wcm)
#      2          98         62490.8            0.25     Successful search (ES-wcm)
#      2         100         62474.7            0.25     Successful search (ES-wcm)
#      2         103         62433.9            0.25     Successful search (ES-wcm)
#      2         108         62431.4            0.25     Successful search (ES-wcm)
#      2         109         62429.4            0.25     Successful search (ES-ell)
#      2         112         62402.7            0.25     Successful search (ES-wcm)
#      2         113         62386.2            0.25     Successful search (ES-wcm)
#      2         115         62360.4            0.25     Successful search (ES-wcm)
#      2         120         62352.4            0.25     Successful search (ES-wcm)
#      2         121         62339.9            0.25     Successful search (ES-wcm)
#      2         122         62320.1            0.25     Successful search (ES-wcm)
#      2         125         62301.2            0.25     Successful search (ES-wcm)
#      2         126         62290.6            0.25     Successful search (ES-wcm)
#      2         132           62285            0.25     Successful search (ES-wcm)
#      2         133         62284.4            0.25     Successful search (ES-wcm)
#      2         135         62281.8            0.25     Successful search (ES-wcm)
#      2         142         62278.1            0.25     Successful search (ES-wcm)
#      2         143         62273.6            0.25     Successful search (ES-wcm)
#      2         144         62272.8            0.25     Successful search (ES-wcm)
#      2         147         62269.2            0.25     Successful search (ES-wcm)
#      2         151           62268            0.25     Successful search (ES-wcm)
#      2         153         62267.3            0.25     Successful search (ES-wcm)
#      2         155         62266.7            0.25     Successful search (ES-wcm)
#      2         158         62266.6            0.25     Incremental search (ES-wcm)
#      2         161         62266.2            0.25     Successful search (ES-wcm)
#      2         163         62266.1            0.25     Incremental search (ES-wcm)
#      2         168           62266            0.25     Incremental search (ES-wcm)
#      2         170           62266            0.25     Incremental search (ES-wcm)
#      2         183           62266           0.125         Refine grid             Train
#      3         187         62265.9           0.125     Successful search (ES-wcm)
#      3         194         62265.9           0.125     Incremental search (ES-wcm)
#      3         196         62265.9           0.125     Incremental search (ES-ell)
#      3         210         62265.9          0.0625         Refine grid
#      4         213         62265.9          0.0625     Incremental search (ES-wcm)
#      4         230         62265.9         0.03125         Refine grid             Train
#      5         231         62265.9         0.03125     Successful search (ES-ell)
#      5         232         62265.9         0.03125     Successful search (ES-wcm)
#      5         236         62265.9         0.03125     Incremental search (ES-ell)
#      5         238         62265.9         0.03125     Incremental search (ES-wcm)
#      5         243         62265.9         0.03125     Incremental search (ES-wcm)
#      5         257         62265.9        0.015625         Refine grid
#      6         258         62265.9        0.015625     Successful search (ES-ell)
#      6         261         62265.9        0.015625     Incremental search (ES-ell)
#      6         264         62265.9        0.015625     Incremental search (ES-wcm)
#      6         269         62265.9        0.015625     Incremental search (ES-wcm)
#      6         284         62265.9       0.0078125         Refine grid             Train
#      7         289         62265.9       0.0078125     Incremental search (ES-ell)
#      7         304         62265.9      0.00390625         Refine grid
#      8         308         62265.9      0.00390625     Incremental search (ES-ell)
#      8         309         62265.9      0.00390625     Incremental search (ES-wcm)
#      8         324         62265.9      0.00195312         Refine grid             Train
#      9         344         62265.9     0.000488281         Refine grid             Train
#     10         345         62265.9     0.000488281     Incremental search (ES-ell)
#     10         364         62265.9      0.00012207         Refine grid             Train
#     11         369         62265.9      0.00012207     Incremental search (ES-ell)
#     11         370         62265.9      0.00012207     Incremental search (ES-wcm)
#     11         384         62265.9     3.05176e-05         Refine grid             Train
#     12         386         62265.9     3.05176e-05     Incremental search (ES-ell)
#     12         388         62265.9     3.05176e-05     Incremental search (ES-ell)
#     12         391         62265.9     3.05176e-05     Incremental search (ES-wcm)
#     12         404         62265.9     7.62939e-06         Refine grid             Train
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 62265.86208796175
#
# Optimization result: [ 0.22896624 19.67968509  2.08916217 95.68391168  0.14738867 87.19148423
#   1.        ], 62265.86208796175
# Starting optimization with initial params: [0.25, 30, 0.75, 60, 0.1, 50, 0.1]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         73159.3               1                                 Uncertainty test
#      0          10         64771.5               1         Initial mesh            Initial points
#      0          20         64771.5             0.5         Refine grid             Train
#      1          23         63741.8             0.5     Successful search (ES-wcm)
#      1          25         63485.2             0.5     Successful search (ES-ell)
#      1          30         63061.9             0.5     Successful search (ES-ell)
#      1          33         62849.5             0.5     Successful search (ES-wcm)
#      1          37         62721.4             0.5     Successful search (ES-wcm)
#      1          41         62719.2             0.5     Successful search (ES-wcm)
#      1          44         62683.3             0.5     Successful search (ES-wcm)
#      1          51         62670.8             0.5     Successful search (ES-wcm)
#      1          54         62659.2             0.5     Successful search (ES-wcm)
#      1          55         62600.8             0.5     Successful search (ES-wcm)
#      1          59         62567.4             0.5     Successful search (ES-ell)
#      1          68         62547.5             0.5     Successful search (ES-ell)
#      1          73         62544.9             0.5     Successful search (ES-ell)
#      1          81         62540.4             0.5     Successful search (ES-ell)
#      1          82         62536.3             0.5     Successful search (ES-ell)
#      1          86         62525.2             0.5     Successful search (ES-ell)
#      1          90         62519.3             0.5     Successful search (ES-ell)
#      1          92         62510.1             0.5     Successful search (ES-ell)
#      1          94         62498.5             0.5     Successful search (ES-ell)
#      1         100         62487.4             0.5     Successful search (ES-ell)
#      1         103         62439.7             0.5     Successful search (ES-ell)
#      1         105           62425             0.5     Successful search (ES-ell)
#      1         111         62414.8             0.5     Successful search (ES-ell)
#      1         115         62394.2             0.5     Successful search (ES-ell)
#      1         116         62388.9             0.5     Successful search (ES-wcm)
#      1         120         62328.7             0.5     Successful search (ES-wcm)
#      1         122         62280.8             0.5     Successful search (ES-wcm)
#      1         131         62276.6             0.5     Successful search (ES-wcm)
#      1         132         62273.7             0.5     Successful search (ES-wcm)
#      1         135         62267.6             0.5     Successful search (ES-wcm)
#      1         154         62267.6            0.25         Refine grid             Train
#      2         156         62267.3            0.25     Successful search (ES-wcm)
#      2         159         62267.1            0.25     Successful search (ES-wcm)
#      2         162         62266.7            0.25     Successful search (ES-wcm)
#      2         166           62266            0.25     Successful search (ES-wcm)
#      2         168         62265.9            0.25     Incremental search (ES-wcm)
#      2         171         62265.9            0.25     Incremental search (ES-wcm)
#      2         186         62265.9           0.125         Refine grid             Train
#      3         193         62265.9           0.125     Incremental search (ES-wcm)
#      3         205         62265.9          0.0625         Refine grid
#      4         212         62265.9          0.0625     Incremental search (ES-wcm)
#      4         225         62265.9         0.03125         Refine grid
#      5         227         62265.9         0.03125     Successful search (ES-wcm)
#      5         228         62265.9         0.03125     Incremental search (ES-wcm)
#      5         231         62265.9         0.03125     Incremental search (ES-wcm)
#      5         234         62265.9         0.03125     Incremental search (ES-wcm)
#      5         238         62265.9         0.03125     Incremental search (ES-wcm)
#      5         252         62265.9        0.015625         Refine grid
#      6         253         62265.9        0.015625     Incremental search (ES-wcm)
#      6         259         62265.9        0.015625     Incremental search (ES-wcm)
#      6         272         62265.9       0.0078125         Refine grid             Train
#      7         275         62265.9       0.0078125     Incremental search (ES-wcm)
#      7         277         62265.9       0.0078125     Incremental search (ES-wcm)
#      7         292         62265.9      0.00390625         Refine grid
#      8         294         62265.9      0.00390625     Incremental search (ES-ell)
#      8         312         62265.9     0.000976562         Refine grid             Train
#      9         332         62265.9     0.000244141         Refine grid             Train
#     10         339         62265.9     0.000244141     Incremental search (ES-wcm)
#     10         352         62265.9     6.10352e-05         Refine grid
#     11         372         62265.9     1.52588e-05         Refine grid             Train
#     12         373         62265.9     1.52588e-05     Incremental search (ES-wcm)
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 62265.862102201136
#
# Optimization result: [ 0.2289533  19.68437005  2.08819864 95.68218118  0.14740145 87.19841679
#   1.        ], 62265.862102201136
# 50
# Starting optimization with initial params: [0.1, 35, 1, 40, 0.08, 20, 0.2]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         73915.1               1                                 Uncertainty test
#      0          10         60818.7               1         Initial mesh            Initial points
#      0          19         60457.3               1       Successful poll           Train
#      1          24         59673.5               1     Successful search (ES-wcm)
#      1          26         59630.7               1     Successful search (ES-wcm)
#      1          32           59488               1     Successful search (ES-wcm)
#      1          39         59463.1               1     Successful search (ES-wcm)
#      1          44         59260.3               1     Successful search (ES-ell)
#      1          45         58955.6               1     Successful search (ES-ell)
#      1          50         58882.4               1     Successful search (ES-ell)
#      1          52         58862.3               1     Successful search (ES-ell)
#      1          71         58862.3             0.5         Refine grid             Train
#      2          74         58838.1             0.5     Successful search (ES-ell)
#      2          80         58826.1             0.5     Successful search (ES-ell)
#      2          85         58771.2             0.5     Successful search (ES-ell)
#      2          90         58767.3             0.5     Successful search (ES-wcm)
#      2          92         58742.3             0.5     Successful search (ES-ell)
#      2          96         58698.6             0.5     Successful search (ES-ell)
#      2          98         58676.3             0.5     Successful search (ES-ell)
#      2         101         58655.1             0.5     Successful search (ES-ell)
#      2         102         58605.1             0.5     Successful search (ES-ell)
#      2         112         58565.4             0.5     Successful search (ES-ell)
#      2         115         58543.2             0.5     Successful search (ES-ell)
#      2         119         58482.7             0.5     Successful search (ES-ell)
#      2         127         58482.1             0.5     Successful search (ES-ell)
#      2         130         58471.2             0.5     Successful search (ES-ell)
#      2         136         58464.5             0.5     Successful search (ES-ell)
#      2         141         58456.6             0.5     Successful search (ES-ell)
#      2         145         58448.5             0.5     Successful search (ES-ell)
#      2         147         58446.1             0.5     Successful search (ES-ell)
#      2         148         58441.1             0.5     Successful search (ES-ell)
#      2         150         58430.3             0.5     Successful search (ES-ell)
#      2         155         58425.7             0.5     Successful search (ES-ell)
#      2         158         58416.1             0.5     Successful search (ES-ell)
#      2         159         58408.7             0.5     Successful search (ES-ell)
#      2         162         58408.6             0.5     Incremental search (ES-ell)
#      2         165         58397.9             0.5     Successful search (ES-ell)
#      2         169         58368.7             0.5     Successful search (ES-ell)
#      2         173         58352.1             0.5     Successful search (ES-ell)
#      2         176         58343.5             0.5     Successful search (ES-ell)
#      2         179           58330             0.5     Successful search (ES-wcm)
#      2         182         58312.1             0.5     Successful search (ES-wcm)
#      2         189         58285.9             0.5     Successful search (ES-wcm)
#      2         190         58274.7             0.5     Successful search (ES-wcm)
#      2         196         58262.2             0.5     Successful search (ES-wcm)
#      2         197         58254.8             0.5     Successful search (ES-wcm)
#      2         199         58250.8             0.5     Successful search (ES-wcm)
#      2         202         58237.9             0.5     Successful search (ES-wcm)
#      2         207         58234.6             0.5     Successful search (ES-wcm)
#      2         208         58225.6             0.5     Successful search (ES-wcm)
#      2         210           58224             0.5     Successful search (ES-wcm)
#      2         212         58222.7             0.5     Successful search (ES-wcm)
#      2         218         58222.2             0.5     Successful search (ES-wcm)
#      2         222         58222.2             0.5     Incremental search (ES-wcm)
#      2         224           58222             0.5     Incremental search (ES-ell)
#      2         236           58222            0.25         Refine grid             Train
#      3         240         58221.9            0.25     Incremental search (ES-wcm)
#      3         254         58221.9           0.125         Refine grid
#      4         255         58221.9           0.125     Incremental search (ES-wcm)
#      4         261         58221.9           0.125     Incremental search (ES-ell)
# ...
#      1          81         66545.6               1     Successful search (ES-wcm)
#      1          87         66527.9               1     Successful search (ES-ell)
#      1          93         66510.1               1     Successful search (ES-ell)
#      1          95         66487.4               1     Successful search (ES-ell)
#      1         110         66487.4             0.5         Refine grid
#      2         114         66486.8             0.5     Successful search (ES-ell)
#      2         116         66478.9             0.5     Successful search (ES-wcm)
#      2         124         66478.7             0.5     Incremental search (ES-wcm)
#      2         135         66478.7            0.25         Refine grid             Train
#      3         138         66472.3            0.25     Successful search (ES-wcm)
#      3         140         66467.3            0.25     Successful search (ES-wcm)
#      3         144         66464.9            0.25     Successful search (ES-wcm)
#      3         148         66457.9            0.25     Successful search (ES-wcm)
#      3         153         66452.6            0.25     Successful search (ES-wcm)
#      3         154         66442.2            0.25     Successful search (ES-wcm)
#      3         161         66440.1            0.25     Successful search (ES-wcm)
#      3         162           66440            0.25     Successful search (ES-wcm)
#      3         169         66437.7            0.25     Successful search (ES-wcm)
#      3         170         66436.6            0.25     Successful search (ES-wcm)
#      3         171         66435.1            0.25     Successful search (ES-wcm)
#      3         176         66431.9            0.25     Successful search (ES-wcm)
#      3         177         66426.5            0.25     Successful search (ES-wcm)
#      3         179         66426.4            0.25     Incremental search (ES-wcm)
#      3         181         66425.6            0.25     Successful search (ES-wcm)
#      3         184         66424.1            0.25     Successful search (ES-wcm)
#      3         185         66420.9            0.25     Successful search (ES-wcm)
#      3         189         66417.6            0.25     Successful search (ES-wcm)
#      3         191         66412.9            0.25     Successful search (ES-wcm)
#      3         193         66410.1            0.25     Successful search (ES-wcm)
#      3         196         66408.3            0.25     Successful search (ES-wcm)
#      3         200         66406.1            0.25     Successful search (ES-wcm)
#      3         202         66405.5            0.25     Successful search (ES-wcm)
#      3         206         66404.3            0.25     Successful search (ES-wcm)
#      3         210         66402.7            0.25     Successful search (ES-wcm)
#      3         211           66402            0.25     Successful search (ES-wcm)
#      3         213         66400.6            0.25     Successful search (ES-wcm)
#      3         216         66399.5            0.25     Successful search (ES-wcm)
#      3         218         66399.1            0.25     Successful search (ES-wcm)
#      3         222         66392.6            0.25     Successful search (ES-wcm)
#      3         224         66387.6            0.25     Successful search (ES-wcm)
#      3         225         66386.8            0.25     Successful search (ES-ell)
#      3         226         66385.8            0.25     Successful search (ES-ell)
#      3         228         66385.6            0.25     Successful search (ES-ell)
#      3         231           66385            0.25     Successful search (ES-ell)
#      3         236         66384.9            0.25     Incremental search (ES-ell)
#      3         240         66384.7            0.25     Successful search (ES-wcm)
#      3         246         66384.7            0.25     Incremental search (ES-ell)
#      3         259         66384.7           0.125         Refine grid
#      4         263         66384.7           0.125     Incremental search (ES-wcm)
#      4         266         66384.7           0.125     Incremental search (ES-wcm)
#      4         279         66384.7          0.0625         Refine grid
#      5         283         66384.7          0.0625     Incremental search (ES-wcm)
#      5         299         66384.7         0.03125         Refine grid             Train
#      6         302         66384.7         0.03125     Incremental search (ES-wcm)
#      6         319         66384.7        0.015625         Refine grid             Train
#      7         339         66384.7       0.0078125         Refine grid             Train
#      8         359         66384.7      0.00195312         Refine grid             Train
#      9         362         66384.7      0.00195312     Incremental search (ES-wcm)
#      9         379         66384.7     0.000488281         Refine grid             Train
#     10         399         66384.7      0.00012207         Refine grid             Train
#     11         419         66384.7     3.05176e-05         Refine grid             Train
#     12         422         66384.7     3.05176e-05     Incremental search (ES-wcm)
#     12         425         66384.7     3.05176e-05     Incremental search (ES-ell)
#     12         439         66384.7     7.62939e-06         Refine grid
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 66384.70613039428
#
# Optimization result: [ 0.13282347 33.86568407  0.87374316 82.97538555  0.0847553  71.03792365
#   1.        ], 66384.70613039428
# Starting optimization with initial params: [0.2, 20, 0.5, 50, 0.06, 30, 0.3]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2          118793               1                                 Uncertainty test
#      0          10         68397.3               1         Initial mesh            Initial points
#      0          19           67981               1       Successful poll           Train
#      1          36           67981             0.5         Refine grid             Train
#      2          38         67552.5             0.5     Successful search (ES-wcm)
#      2          43         67310.8             0.5     Successful search (ES-wcm)
#      2          46         67084.4             0.5     Successful search (ES-ell)
#      2          50         66935.9             0.5     Successful search (ES-ell)
#      2          57         66909.5             0.5     Successful search (ES-ell)
#      2          59         66675.1             0.5     Successful search (ES-ell)
#      2          66         66637.1             0.5     Successful search (ES-ell)
#      2          67         66622.7             0.5     Successful search (ES-ell)
#      2          71         66606.8             0.5     Successful search (ES-ell)
#      2          73         66542.5             0.5     Successful search (ES-ell)
#      2          78         66474.4             0.5     Successful search (ES-ell)
#      2          81         66455.9             0.5     Successful search (ES-wcm)
#      2          88         66445.1             0.5     Successful search (ES-wcm)
#      2          91         66436.3             0.5     Successful search (ES-wcm)
#      2          95         66434.7             0.5     Successful search (ES-wcm)
#      2          99         66433.5             0.5     Successful search (ES-wcm)
#      2         101         66428.2             0.5     Successful search (ES-wcm)
#      2         105         66422.9             0.5     Successful search (ES-wcm)
#      2         111         66419.5             0.5     Successful search (ES-wcm)
#      2         112         66418.6             0.5     Successful search (ES-wcm)
#      2         113         66414.1             0.5     Successful search (ES-wcm)
#      2         117         66408.2             0.5     Successful search (ES-wcm)
#      2         125         66402.9             0.5     Successful search (ES-ell)
#      2         127           66401             0.5     Successful search (ES-wcm)
#      2         131         66399.7             0.5     Successful search (ES-ell)
#      2         133         66397.1             0.5     Successful search (ES-ell)
#      2         137         66392.2             0.5     Successful search (ES-ell)
#      2         146         66391.7             0.5     Successful search (ES-ell)
#      2         153         66386.9             0.5     Successful search (ES-ell)
#      2         160         66385.8             0.5     Successful search (ES-wcm)
#      2         165         66385.3             0.5     Successful search (ES-wcm)
#      2         168         66385.2             0.5     Incremental search (ES-wcm)
#      2         174         66385.1             0.5     Incremental search (ES-wcm)
#      2         175         66384.9             0.5     Incremental search (ES-wcm)
#      2         187         66384.9            0.25         Refine grid             Train
#      3         191         66384.8            0.25     Successful search (ES-wcm)
#      3         192         66384.8            0.25     Incremental search (ES-wcm)
#      3         198         66384.7            0.25     Incremental search (ES-wcm)
#      3         213         66384.7           0.125         Refine grid
#      4         233         66384.7          0.0625         Refine grid             Train
#      5         253         66384.7         0.03125         Refine grid             Train
#      6         273         66384.7       0.0078125         Refine grid             Train
#      7         276         66384.7       0.0078125     Successful search (ES-wcm)
#      7         300         66384.7      0.00390625         Refine grid             Train
#      8         303         66384.7      0.00390625     Successful search (ES-ell)
#      8         327         66384.7      0.00195312         Refine grid             Train
#      9         331         66384.7      0.00195312     Incremental search (ES-wcm)
#      9         334         66384.7      0.00195312     Incremental search (ES-wcm)
#      9         347         66384.7     0.000976562         Refine grid
#     10         352         66384.7     0.000976562     Incremental search (ES-wcm)
#     10         367         66384.7     0.000488281         Refine grid             Train
#     11         371         66384.7     0.000488281     Incremental search (ES-wcm)
#     11         374         66384.7     0.000488281     Incremental search (ES-wcm)
#     11         387         66384.7      0.00012207         Refine grid             Train
#     12         389         66384.7      0.00012207     Incremental search (ES-wcm)
#     12         391         66384.7      0.00012207     Incremental search (ES-ell)
#     12         394         66384.7      0.00012207     Incremental search (ES-ell)
#     12         407         66384.7     3.05176e-05         Refine grid             Train
#     13         410         66384.7     3.05176e-05     Incremental search (ES-ell)
#     13         411         66384.7     3.05176e-05     Incremental search (ES-wcm)
#     13         427         66384.7     7.62939e-06         Refine grid
#     14         432         66384.7     7.62939e-06     Incremental search (ES-wcm)
#     14         433         66384.7     7.62939e-06     Incremental search (ES-wcm)
#     14         434         66384.7     7.62939e-06     Incremental search (ES-wcm)
#     14         447         66384.7     1.90735e-06         Refine grid
# Optimization terminated: change in the function value less than options['tol_fun'].
# Function value at minimum: 66384.70875715806
#
# Optimization result: [ 0.13329914 33.73163173  0.88247331 83.0200126   0.08483044 71.07082618
#   0.99999998], 66384.70875715806
# Starting optimization with initial params: [0.25, 30, 0.75, 60, 0.1, 50, 0.1]
# Variables (index) internally transformed to log coordinates: [[0 0]
#  [0 2]]
# Beginning optimization of a DETERMINISTIC objective function
#
#  Iteration    f-count         f(x)           MeshScale          Method             Actions
#      0           2         92907.3               1                                 Uncertainty test
#      0          10         68397.3               1         Initial mesh            Initial points
#      0          19           67981               1       Successful poll           Train
#      1          25         67290.2               1     Successful search (ES-wcm)
#      1          32           67059               1     Successful search (ES-wcm)
#      1          40           66922               1     Successful search (ES-ell)
#      1          44         66852.3               1     Successful search (ES-ell)
#      1          47         66840.9               1     Successful search (ES-ell)
#      1          63         66840.9             0.5         Refine grid             Train
#      2          66         66785.9             0.5     Successful search (ES-ell)
#      2          68         66738.6             0.5     Successful search (ES-wcm)
#      2          69         66616.1             0.5     Successful search (ES-wcm)
#      2          73         66607.9             0.5     Successful search (ES-ell)
#      2          80         66595.4             0.5     Successful search (ES-wcm)
#      2          82         66506.8             0.5     Successful search (ES-ell)
#      2          88         66476.7             0.5     Successful search (ES-ell)
#      2          94         66461.3             0.5     Successful search (ES-ell)
#      2         103           66447             0.5     Successful search (ES-ell)
#      2         104         66446.3             0.5     Successful search (ES-ell)
#      2         107         66437.3             0.5     Successful search (ES-ell)
#      2         110           66437             0.5     Incremental search (ES-ell)
#      2         116         66432.8             0.5     Successful search (ES-ell)
#      2         121         66432.7             0.5     Incremental search (ES-ell)
#      2         125         66428.4             0.5     Successful search (ES-ell)
#      2         131         66425.8             0.5     Successful search (ES-ell)
#      2         132         66423.2             0.5     Successful search (ES-ell)
#      2         136         66422.7             0.5     Successful search (ES-ell)
#      2         139         66420.1             0.5     Successful search (ES-ell)
#      2         144         66415.7             0.5     Successful search (ES-ell)
#      2         146         66414.1             0.5     Successful search (ES-ell)
#      2         151         66409.3             0.5     Successful search (ES-ell)
#      2         153         66404.2             0.5     Successful search (ES-wcm)
