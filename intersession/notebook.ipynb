# %%
from intersession import *

# %% [markdown]
# # Intersession analysis per box

# %% [markdown]
# ## Accuracy

# %% [markdown]
# ### Single subjects

# %%
intersession_across_boxes(protocol='stage_training_v6', experiment='2AFC_6', variable='Accuracy', mean=False, update=False, to_csv=False)
# Out:
# glue_animals_intersessions took 0.07 seconds to run
# intersession_across_boxes took 0.19 seconds to run

# %% [markdown]
# ### Mean

# %%
intersession_across_boxes(protocol='stage_training_v6', experiment='2AFC_6', variable='Accuracy', mean=True, update=False, to_csv=False)
# Out:
# glue_animals_intersessions took 0.07 seconds to run
# intersession_across_boxes took 0.15 seconds to run

# %% [markdown]
# ## Lateral bias

# %% [markdown]
# ### Single subjects

# %%
intersession_across_boxes(protocol='stage_training_v6', experiment='2AFC_6', variable='LateralBias', mean=False, update=False, to_csv=False)
# Out:
# glue_animals_intersessions took 0.09 seconds to run
# intersession_across_boxes took 0.19 seconds to run

# %% [markdown]
# ### Mean

# %%
intersession_across_boxes(protocol='stage_training_v6', experiment='2AFC_6', variable='LateralBias', mean=True, update=False, to_csv=False)
# Out:
# glue_animals_intersessions took 0.09 seconds to run
# intersession_across_boxes took 0.26 seconds to run
